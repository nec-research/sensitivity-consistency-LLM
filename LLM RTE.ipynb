# %%
import os
import ray
import random
import datetime

import numpy as np

import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt

from util import *
from estimator import *
from evaluator import run_grid_search

os.environ.pop('http_proxy', None)
# Out:
# 'http://192.168.0.1:8123'

# %% [markdown]
# ### Parse RTE data

# %%
input_file = Path('./data/RTE/train.jsonl')
results_folder = Path('./data/RTE_RESULTS')
processed_data_file = Path('./data/RTE_RESULTS/data.json')
dataset = 'RTE'
class_labels = ["entailment", "contradiction/neutral", "N/A"]
class_labels_to_id = {c_name: i for i, c_name in enumerate(class_labels)}

def parse_CB(input_file):
    
    data_list = []

    # Open the JSONL file and read line by line
    with open(input_file, 'r') as file:
        for line in file:
            # Parse JSON from each line
            json_obj = json.loads(line)

            # Extract relevant fields from the JSON object
            idx = json_obj['idx']
            premise = json_obj['premise']
            hypothesis = json_obj['hypothesis']
            label = json_obj['label']

            if label == 'not_entailment':
                label = 'contradiction/neutral'
            
            # Prepare the input string as specified
            input_text = f"Premise: {premise}\nHypothesis: {hypothesis}"

            # Create a new dictionary in the desired format
            new_entry = {
                "id": idx,
                "input": input_text,
                "class": label
            }

            # Append the new dictionary to the data list
            data_list.append(new_entry)

    return data_list


if not os.path.exists(processed_data_file):
    data_list = parse_CB(input_file)  # do not count NA

    # Serialize the dictionary to a JSON string
    json_data = json.dumps(data_list)

    # Write the JSON string to a file
    with open(processed_data_file, 'w') as f:
        f.write(json_data)
else:
    with open(processed_data_file, 'r') as f:
        data_list = json.load(f)


n_samples = len(data_list)
sample_ids = [s["id"] for s in data_list]

def class_extractor_fun(text):
    # we might want to check if more than a word is returned, but does not seem strictly necessary
    for l in class_labels:
        if l.lower() in text.lower():
            return l
    # if no label has been found
    return "N/A"

# %%
len(data_list)
# s_id = 1
# print(data_list[s_id]['input'])
# print(data_list[s_id]['class'])
# Out:
# 2490

# %% [markdown]
# ## Run a grid search over parameters

# %%
question_to_rewrite = "You are given a premise and a hypothesis as input. Determine is there is entailment or a contradiction/neutral statement."

prompt_simple = [
    ["system", "You are a text entailment system."],
    ["user", "You are given a premise and a hypothesis as input. You are given a premise and a hypothesis as input. Determine is there is entailment or a contradiction/neutral statement.\nAnswer with the class name only.\nThe possible classes are: entailment and contradiction/neutral.\nHere is the text: {summary}"]    
]

prompt_instruct = [
    ["system", "You are a text entailment system."],
    ["user", "You are given a premise and a hypothesis as input. You are given a premise and a hypothesis as input. Determine is there is entailment or a contradiction/neutral statement.\nAnswer with the class name only.\nThe possible classes are: \n- entailment: a logical relationship where the meaning of one text (the hypothesis) is necessarily implied by another text (the premise), \n- contradiction/neutral: contradictions or neutral statements that are not entailments\n\nHere is the text: {summary}"]    
]


prompt_fewshot = [
    ["system", "You are a text entailment system."],
    ["user",
     "You are given a premise and a hypothesis as input. Determine is there is entailment or a contradiction/neutral statement.\nAnswer with the class name only.\nThe possible classes are: entailment and contradiction/neutral.\n"
     "Here are a few examples:\n"
     "Example 1:\n"
     "Premise: Dana Reeve, the widow of the actor Christopher Reeve, has died of lung cancer at age 44, according to the Christopher Reeve Foundation. Hypothesis:\n Christopher Reeve had an accident. Label: contradiction/neutral\n"
     "Example 2:\n"
     "Premise: And I don't want to have to lie to them. The kidnappers have given us until October the eleventh to deliver the document and I haven't despaired of finding it before then. But if the police learn I 've been to America they 'll ask why. Hypothesis:\n he's been to America. Label: entailment\n"
     "Here is the text: {summary}"]
]


prompt_types = {"simple": prompt_simple,
               "instruct": prompt_instruct,
               "fewshot": prompt_fewshot}

llms = ['llama3', 'mixtral']#, 'gpt-3.5', 'gpt-4o']
Qs = [30] # number of equivalent but alternative questions compared to original question
temp_questions = [0.]#list(np.arange(0., 1.25, 0.25))  # temperature of the LLM used to produce questions
As = [1] # number of alternative answers for each questions
temp_answers =  [0.] # list(np.arange(0., 1.5, 0.25))  # temperature of the LLM used to produce answers

samples = data_list
n_samples = len(samples)
print(f'Num test examples is {len(samples)}')
# Out:
# Num test examples is 2490

# %%
run_grid_search(samples,
                llms,
                prompt_types,
                Qs,
                temp_questions,
                question_to_rewrite,
                As,
                temp_answers,
                class_labels,
                class_extractor_fun,
                results_folder)
# Out:
# 2024-08-03 20:17:58,080	INFO worker.py:1621 -- Started a local Ray instance.
# Skipping test 0_llama3_30_1_0.0_0.0
# Skipping test 1_llama3_30_1_0.0_0.0
# Skipping test 2_llama3_30_1_0.0_0.0
# Skipping test 3_llama3_30_1_0.0_0.0
# Skipping test 4_llama3_30_1_0.0_0.0
# Skipping test 5_llama3_30_1_0.0_0.0
# Skipping test 6_llama3_30_1_0.0_0.0
# Skipping test 7_llama3_30_1_0.0_0.0
# Skipping test 8_llama3_30_1_0.0_0.0
# Skipping test 9_llama3_30_1_0.0_0.0
# Skipping test 10_llama3_30_1_0.0_0.0
# Skipping test 11_llama3_30_1_0.0_0.0
# Skipping test 12_llama3_30_1_0.0_0.0
# Skipping test 13_llama3_30_1_0.0_0.0
# Skipping test 14_llama3_30_1_0.0_0.0
# Skipping test 15_llama3_30_1_0.0_0.0
# Skipping test 16_llama3_30_1_0.0_0.0
# Skipping test 17_llama3_30_1_0.0_0.0
# Skipping test 18_llama3_30_1_0.0_0.0
# Skipping test 19_llama3_30_1_0.0_0.0
# Skipping test 20_llama3_30_1_0.0_0.0
# Skipping test 21_llama3_30_1_0.0_0.0
# Skipping test 22_llama3_30_1_0.0_0.0
# Skipping test 23_llama3_30_1_0.0_0.0
# Skipping test 24_llama3_30_1_0.0_0.0
# Skipping test 25_llama3_30_1_0.0_0.0
# Skipping test 26_llama3_30_1_0.0_0.0
# Skipping test 27_llama3_30_1_0.0_0.0
# Skipping test 28_llama3_30_1_0.0_0.0
# Skipping test 29_llama3_30_1_0.0_0.0
# Skipping test 30_llama3_30_1_0.0_0.0
# Skipping test 31_llama3_30_1_0.0_0.0
# Skipping test 32_llama3_30_1_0.0_0.0
# Skipping test 33_llama3_30_1_0.0_0.0
# Skipping test 34_llama3_30_1_0.0_0.0
# Skipping test 35_llama3_30_1_0.0_0.0
# Skipping test 36_llama3_30_1_0.0_0.0
# Skipping test 37_llama3_30_1_0.0_0.0
# Skipping test 38_llama3_30_1_0.0_0.0
# Skipping test 39_llama3_30_1_0.0_0.0
# Skipping test 40_llama3_30_1_0.0_0.0
# Skipping test 41_llama3_30_1_0.0_0.0
# Skipping test 42_llama3_30_1_0.0_0.0
# Skipping test 43_llama3_30_1_0.0_0.0
# Skipping test 44_llama3_30_1_0.0_0.0
# Skipping test 45_llama3_30_1_0.0_0.0
# Skipping test 46_llama3_30_1_0.0_0.0
# Skipping test 47_llama3_30_1_0.0_0.0
# Skipping test 48_llama3_30_1_0.0_0.0
# Skipping test 49_llama3_30_1_0.0_0.0
# Skipping test 50_llama3_30_1_0.0_0.0
# Skipping test 51_llama3_30_1_0.0_0.0
# Skipping test 52_llama3_30_1_0.0_0.0
# Skipping test 53_llama3_30_1_0.0_0.0
# Skipping test 54_llama3_30_1_0.0_0.0
# Skipping test 55_llama3_30_1_0.0_0.0
# Skipping test 56_llama3_30_1_0.0_0.0
# Skipping test 57_llama3_30_1_0.0_0.0
# Skipping test 58_llama3_30_1_0.0_0.0
# Skipping test 59_llama3_30_1_0.0_0.0
# Skipping test 60_llama3_30_1_0.0_0.0
# Skipping test 61_llama3_30_1_0.0_0.0
# Skipping test 62_llama3_30_1_0.0_0.0
# Skipping test 63_llama3_30_1_0.0_0.0
# Skipping test 64_llama3_30_1_0.0_0.0
# Skipping test 65_llama3_30_1_0.0_0.0
# Skipping test 66_llama3_30_1_0.0_0.0
# Skipping test 67_llama3_30_1_0.0_0.0
# Skipping test 68_llama3_30_1_0.0_0.0
# Skipping test 69_llama3_30_1_0.0_0.0
# Skipping test 70_llama3_30_1_0.0_0.0
# Skipping test 71_llama3_30_1_0.0_0.0
# Skipping test 72_llama3_30_1_0.0_0.0
# Skipping test 73_llama3_30_1_0.0_0.0
# Skipping test 74_llama3_30_1_0.0_0.0
# Skipping test 75_llama3_30_1_0.0_0.0
# Skipping test 76_llama3_30_1_0.0_0.0
# Skipping test 77_llama3_30_1_0.0_0.0
# Skipping test 78_llama3_30_1_0.0_0.0
# Skipping test 79_llama3_30_1_0.0_0.0
# Skipping test 80_llama3_30_1_0.0_0.0
# Skipping test 81_llama3_30_1_0.0_0.0
# Skipping test 82_llama3_30_1_0.0_0.0
# Skipping test 83_llama3_30_1_0.0_0.0
# Skipping test 84_llama3_30_1_0.0_0.0
# Skipping test 85_llama3_30_1_0.0_0.0
# Skipping test 86_llama3_30_1_0.0_0.0
# Skipping test 87_llama3_30_1_0.0_0.0
# Skipping test 88_llama3_30_1_0.0_0.0
# Skipping test 89_llama3_30_1_0.0_0.0
# Skipping test 90_llama3_30_1_0.0_0.0
# Skipping test 91_llama3_30_1_0.0_0.0
# Skipping test 92_llama3_30_1_0.0_0.0
# Skipping test 93_llama3_30_1_0.0_0.0
# Skipping test 94_llama3_30_1_0.0_0.0
# Skipping test 95_llama3_30_1_0.0_0.0
# Skipping test 96_llama3_30_1_0.0_0.0
# Skipping test 97_llama3_30_1_0.0_0.0
# Skipping test 98_llama3_30_1_0.0_0.0
# Skipping test 99_llama3_30_1_0.0_0.0
# Skipping test 100_llama3_30_1_0.0_0.0
# Skipping test 101_llama3_30_1_0.0_0.0
# Skipping test 102_llama3_30_1_0.0_0.0
# Skipping test 103_llama3_30_1_0.0_0.0
# Skipping test 104_llama3_30_1_0.0_0.0
# Skipping test 105_llama3_30_1_0.0_0.0
# Skipping test 106_llama3_30_1_0.0_0.0
# Skipping test 107_llama3_30_1_0.0_0.0
# Skipping test 108_llama3_30_1_0.0_0.0
# Skipping test 109_llama3_30_1_0.0_0.0
# Skipping test 110_llama3_30_1_0.0_0.0
# Skipping test 111_llama3_30_1_0.0_0.0
# Skipping test 112_llama3_30_1_0.0_0.0
# Skipping test 113_llama3_30_1_0.0_0.0
# Skipping test 114_llama3_30_1_0.0_0.0
# Skipping test 115_llama3_30_1_0.0_0.0
# Skipping test 116_llama3_30_1_0.0_0.0
# Skipping test 117_llama3_30_1_0.0_0.0
# Skipping test 118_llama3_30_1_0.0_0.0
# Skipping test 119_llama3_30_1_0.0_0.0
# Skipping test 120_llama3_30_1_0.0_0.0
# Skipping test 121_llama3_30_1_0.0_0.0
# Skipping test 122_llama3_30_1_0.0_0.0
# Skipping test 123_llama3_30_1_0.0_0.0
# Skipping test 124_llama3_30_1_0.0_0.0
# Skipping test 125_llama3_30_1_0.0_0.0
# Skipping test 126_llama3_30_1_0.0_0.0
# Skipping test 127_llama3_30_1_0.0_0.0
# Skipping test 128_llama3_30_1_0.0_0.0
# Skipping test 129_llama3_30_1_0.0_0.0
# Skipping test 130_llama3_30_1_0.0_0.0
# Skipping test 131_llama3_30_1_0.0_0.0
# Skipping test 132_llama3_30_1_0.0_0.0
# Skipping test 133_llama3_30_1_0.0_0.0
# Skipping test 134_llama3_30_1_0.0_0.0
# Skipping test 135_llama3_30_1_0.0_0.0
# Skipping test 136_llama3_30_1_0.0_0.0
# Skipping test 137_llama3_30_1_0.0_0.0
# Skipping test 138_llama3_30_1_0.0_0.0
# Skipping test 139_llama3_30_1_0.0_0.0
# Skipping test 140_llama3_30_1_0.0_0.0
# Skipping test 141_llama3_30_1_0.0_0.0
# Skipping test 142_llama3_30_1_0.0_0.0
# Skipping test 143_llama3_30_1_0.0_0.0
# Skipping test 144_llama3_30_1_0.0_0.0
# Skipping test 145_llama3_30_1_0.0_0.0
# Skipping test 146_llama3_30_1_0.0_0.0
# Skipping test 147_llama3_30_1_0.0_0.0
# Skipping test 148_llama3_30_1_0.0_0.0
# Skipping test 149_llama3_30_1_0.0_0.0
# Skipping test 150_llama3_30_1_0.0_0.0
# Skipping test 151_llama3_30_1_0.0_0.0
# Skipping test 152_llama3_30_1_0.0_0.0
# Skipping test 153_llama3_30_1_0.0_0.0
# Skipping test 154_llama3_30_1_0.0_0.0
# Skipping test 155_llama3_30_1_0.0_0.0
# Skipping test 156_llama3_30_1_0.0_0.0
# Skipping test 157_llama3_30_1_0.0_0.0
# Skipping test 158_llama3_30_1_0.0_0.0
# Skipping test 159_llama3_30_1_0.0_0.0
# Skipping test 160_llama3_30_1_0.0_0.0
# Skipping test 161_llama3_30_1_0.0_0.0
# Skipping test 162_llama3_30_1_0.0_0.0
# Skipping test 163_llama3_30_1_0.0_0.0
# Skipping test 164_llama3_30_1_0.0_0.0
# Skipping test 165_llama3_30_1_0.0_0.0
# Skipping test 166_llama3_30_1_0.0_0.0
# Skipping test 167_llama3_30_1_0.0_0.0
# Skipping test 168_llama3_30_1_0.0_0.0
# Skipping test 169_llama3_30_1_0.0_0.0
# Skipping test 170_llama3_30_1_0.0_0.0
# Skipping test 171_llama3_30_1_0.0_0.0
# Skipping test 172_llama3_30_1_0.0_0.0
# Skipping test 173_llama3_30_1_0.0_0.0
# Skipping test 174_llama3_30_1_0.0_0.0
# Skipping test 175_llama3_30_1_0.0_0.0
# Skipping test 176_llama3_30_1_0.0_0.0
# Skipping test 177_llama3_30_1_0.0_0.0
# Skipping test 178_llama3_30_1_0.0_0.0
# Skipping test 179_llama3_30_1_0.0_0.0
# Skipping test 180_llama3_30_1_0.0_0.0
# Skipping test 181_llama3_30_1_0.0_0.0
# Skipping test 182_llama3_30_1_0.0_0.0
# Skipping test 183_llama3_30_1_0.0_0.0
# Skipping test 184_llama3_30_1_0.0_0.0
# Skipping test 185_llama3_30_1_0.0_0.0
# Skipping test 186_llama3_30_1_0.0_0.0
# Skipping test 187_llama3_30_1_0.0_0.0
# Skipping test 188_llama3_30_1_0.0_0.0
# Skipping test 189_llama3_30_1_0.0_0.0
# Skipping test 190_llama3_30_1_0.0_0.0
# Skipping test 191_llama3_30_1_0.0_0.0
# Skipping test 192_llama3_30_1_0.0_0.0
# Skipping test 193_llama3_30_1_0.0_0.0
# Skipping test 194_llama3_30_1_0.0_0.0
# Skipping test 195_llama3_30_1_0.0_0.0
# Skipping test 196_llama3_30_1_0.0_0.0
# Skipping test 197_llama3_30_1_0.0_0.0
# Skipping test 198_llama3_30_1_0.0_0.0
# Skipping test 199_llama3_30_1_0.0_0.0
# Skipping test 200_llama3_30_1_0.0_0.0
# Skipping test 201_llama3_30_1_0.0_0.0
# Skipping test 202_llama3_30_1_0.0_0.0
# Skipping test 203_llama3_30_1_0.0_0.0
# Skipping test 204_llama3_30_1_0.0_0.0
# Skipping test 205_llama3_30_1_0.0_0.0
# Skipping test 206_llama3_30_1_0.0_0.0
# Skipping test 207_llama3_30_1_0.0_0.0
# Skipping test 208_llama3_30_1_0.0_0.0
# Skipping test 209_llama3_30_1_0.0_0.0
# Skipping test 210_llama3_30_1_0.0_0.0
# Skipping test 211_llama3_30_1_0.0_0.0
# Skipping test 212_llama3_30_1_0.0_0.0
# Skipping test 213_llama3_30_1_0.0_0.0
# Skipping test 214_llama3_30_1_0.0_0.0
# Skipping test 215_llama3_30_1_0.0_0.0
# Skipping test 216_llama3_30_1_0.0_0.0
# Skipping test 217_llama3_30_1_0.0_0.0
# Skipping test 218_llama3_30_1_0.0_0.0
# Skipping test 219_llama3_30_1_0.0_0.0
# Skipping test 220_llama3_30_1_0.0_0.0
# Skipping test 221_llama3_30_1_0.0_0.0
# Skipping test 222_llama3_30_1_0.0_0.0
# Skipping test 223_llama3_30_1_0.0_0.0
# Skipping test 224_llama3_30_1_0.0_0.0
# Skipping test 225_llama3_30_1_0.0_0.0
# Skipping test 226_llama3_30_1_0.0_0.0
# Skipping test 227_llama3_30_1_0.0_0.0
# Skipping test 228_llama3_30_1_0.0_0.0
# Skipping test 229_llama3_30_1_0.0_0.0
# Skipping test 230_llama3_30_1_0.0_0.0
# Skipping test 231_llama3_30_1_0.0_0.0
# Skipping test 232_llama3_30_1_0.0_0.0
# Skipping test 233_llama3_30_1_0.0_0.0
# Skipping test 234_llama3_30_1_0.0_0.0
# Skipping test 235_llama3_30_1_0.0_0.0
# Skipping test 236_llama3_30_1_0.0_0.0
# Skipping test 237_llama3_30_1_0.0_0.0
# Skipping test 238_llama3_30_1_0.0_0.0
# Skipping test 239_llama3_30_1_0.0_0.0
# Skipping test 240_llama3_30_1_0.0_0.0
# Skipping test 241_llama3_30_1_0.0_0.0
# Skipping test 242_llama3_30_1_0.0_0.0
# Skipping test 243_llama3_30_1_0.0_0.0
# Skipping test 244_llama3_30_1_0.0_0.0
# Skipping test 245_llama3_30_1_0.0_0.0
# Skipping test 246_llama3_30_1_0.0_0.0
# Skipping test 247_llama3_30_1_0.0_0.0
# Skipping test 248_llama3_30_1_0.0_0.0
# Skipping test 249_llama3_30_1_0.0_0.0
# Skipping test 250_llama3_30_1_0.0_0.0
# Skipping test 251_llama3_30_1_0.0_0.0
# Skipping test 252_llama3_30_1_0.0_0.0
# Skipping test 253_llama3_30_1_0.0_0.0
# Skipping test 254_llama3_30_1_0.0_0.0
# Skipping test 255_llama3_30_1_0.0_0.0
# Skipping test 256_llama3_30_1_0.0_0.0
# Skipping test 257_llama3_30_1_0.0_0.0
# Skipping test 258_llama3_30_1_0.0_0.0
# Skipping test 259_llama3_30_1_0.0_0.0
# Skipping test 260_llama3_30_1_0.0_0.0
# Skipping test 261_llama3_30_1_0.0_0.0
# Skipping test 262_llama3_30_1_0.0_0.0
# Skipping test 263_llama3_30_1_0.0_0.0
# Skipping test 264_llama3_30_1_0.0_0.0
# Skipping test 265_llama3_30_1_0.0_0.0
# Skipping test 266_llama3_30_1_0.0_0.0
# Skipping test 267_llama3_30_1_0.0_0.0
# Skipping test 268_llama3_30_1_0.0_0.0
# Skipping test 269_llama3_30_1_0.0_0.0
# Skipping test 270_llama3_30_1_0.0_0.0
# Skipping test 271_llama3_30_1_0.0_0.0
# Skipping test 272_llama3_30_1_0.0_0.0
# Skipping test 273_llama3_30_1_0.0_0.0
# Skipping test 274_llama3_30_1_0.0_0.0
# Skipping test 275_llama3_30_1_0.0_0.0
# Skipping test 276_llama3_30_1_0.0_0.0
# Skipping test 277_llama3_30_1_0.0_0.0
# Skipping test 278_llama3_30_1_0.0_0.0
# Skipping test 279_llama3_30_1_0.0_0.0
# Skipping test 280_llama3_30_1_0.0_0.0
# Skipping test 281_llama3_30_1_0.0_0.0
# Skipping test 282_llama3_30_1_0.0_0.0
# Skipping test 283_llama3_30_1_0.0_0.0
# Skipping test 284_llama3_30_1_0.0_0.0
# Skipping test 285_llama3_30_1_0.0_0.0
# Skipping test 286_llama3_30_1_0.0_0.0
# Skipping test 287_llama3_30_1_0.0_0.0
# Skipping test 288_llama3_30_1_0.0_0.0
# Skipping test 289_llama3_30_1_0.0_0.0
# Skipping test 290_llama3_30_1_0.0_0.0
# Skipping test 291_llama3_30_1_0.0_0.0
# Skipping test 292_llama3_30_1_0.0_0.0
# Skipping test 293_llama3_30_1_0.0_0.0
# Skipping test 294_llama3_30_1_0.0_0.0
# Skipping test 295_llama3_30_1_0.0_0.0
# Skipping test 296_llama3_30_1_0.0_0.0
# Skipping test 297_llama3_30_1_0.0_0.0
# Skipping test 298_llama3_30_1_0.0_0.0
# Skipping test 299_llama3_30_1_0.0_0.0
# Skipping test 300_llama3_30_1_0.0_0.0
# Skipping test 301_llama3_30_1_0.0_0.0
# Skipping test 302_llama3_30_1_0.0_0.0
# Skipping test 303_llama3_30_1_0.0_0.0
# Skipping test 304_llama3_30_1_0.0_0.0
# Skipping test 305_llama3_30_1_0.0_0.0
# Skipping test 306_llama3_30_1_0.0_0.0
# Skipping test 307_llama3_30_1_0.0_0.0
# Skipping test 308_llama3_30_1_0.0_0.0
# Skipping test 309_llama3_30_1_0.0_0.0
# Skipping test 310_llama3_30_1_0.0_0.0
# Skipping test 311_llama3_30_1_0.0_0.0
# Skipping test 312_llama3_30_1_0.0_0.0
# Skipping test 313_llama3_30_1_0.0_0.0
# Skipping test 314_llama3_30_1_0.0_0.0
# Skipping test 315_llama3_30_1_0.0_0.0
# Skipping test 316_llama3_30_1_0.0_0.0
# Skipping test 317_llama3_30_1_0.0_0.0
# Skipping test 318_llama3_30_1_0.0_0.0
# Skipping test 319_llama3_30_1_0.0_0.0
# Skipping test 320_llama3_30_1_0.0_0.0
# Skipping test 321_llama3_30_1_0.0_0.0
# Skipping test 322_llama3_30_1_0.0_0.0
# Skipping test 323_llama3_30_1_0.0_0.0
# Skipping test 324_llama3_30_1_0.0_0.0
# Skipping test 325_llama3_30_1_0.0_0.0
# Skipping test 326_llama3_30_1_0.0_0.0
# Skipping test 327_llama3_30_1_0.0_0.0
# Skipping test 328_llama3_30_1_0.0_0.0
# Skipping test 329_llama3_30_1_0.0_0.0
# Skipping test 330_llama3_30_1_0.0_0.0
# Skipping test 331_llama3_30_1_0.0_0.0
# Skipping test 332_llama3_30_1_0.0_0.0
# Skipping test 333_llama3_30_1_0.0_0.0
# Skipping test 334_llama3_30_1_0.0_0.0
# Skipping test 335_llama3_30_1_0.0_0.0
# Skipping test 336_llama3_30_1_0.0_0.0
# Skipping test 337_llama3_30_1_0.0_0.0
# Skipping test 338_llama3_30_1_0.0_0.0
# Skipping test 339_llama3_30_1_0.0_0.0
# Skipping test 340_llama3_30_1_0.0_0.0
# Skipping test 341_llama3_30_1_0.0_0.0
# Skipping test 342_llama3_30_1_0.0_0.0
# Skipping test 343_llama3_30_1_0.0_0.0
# Skipping test 344_llama3_30_1_0.0_0.0
# Skipping test 345_llama3_30_1_0.0_0.0
# Skipping test 346_llama3_30_1_0.0_0.0
# Skipping test 347_llama3_30_1_0.0_0.0
# Skipping test 348_llama3_30_1_0.0_0.0
# Skipping test 349_llama3_30_1_0.0_0.0
# Skipping test 350_llama3_30_1_0.0_0.0
# Skipping test 351_llama3_30_1_0.0_0.0
# Skipping test 352_llama3_30_1_0.0_0.0
# Skipping test 353_llama3_30_1_0.0_0.0
# Skipping test 354_llama3_30_1_0.0_0.0
# Skipping test 355_llama3_30_1_0.0_0.0
# Skipping test 356_llama3_30_1_0.0_0.0
# Skipping test 357_llama3_30_1_0.0_0.0
# Skipping test 358_llama3_30_1_0.0_0.0
# Skipping test 359_llama3_30_1_0.0_0.0
# Skipping test 360_llama3_30_1_0.0_0.0
# Skipping test 361_llama3_30_1_0.0_0.0
# Skipping test 362_llama3_30_1_0.0_0.0
# Skipping test 363_llama3_30_1_0.0_0.0
# Skipping test 364_llama3_30_1_0.0_0.0
# Skipping test 365_llama3_30_1_0.0_0.0
# Skipping test 366_llama3_30_1_0.0_0.0
# Skipping test 367_llama3_30_1_0.0_0.0
# Skipping test 368_llama3_30_1_0.0_0.0
# Skipping test 369_llama3_30_1_0.0_0.0
# Skipping test 370_llama3_30_1_0.0_0.0
# Skipping test 371_llama3_30_1_0.0_0.0
# Skipping test 372_llama3_30_1_0.0_0.0
# Skipping test 373_llama3_30_1_0.0_0.0
# Skipping test 374_llama3_30_1_0.0_0.0
# Skipping test 375_llama3_30_1_0.0_0.0
# Skipping test 376_llama3_30_1_0.0_0.0
# Skipping test 377_llama3_30_1_0.0_0.0
# Skipping test 378_llama3_30_1_0.0_0.0
# Skipping test 379_llama3_30_1_0.0_0.0
# Skipping test 380_llama3_30_1_0.0_0.0
# Skipping test 381_llama3_30_1_0.0_0.0
# Skipping test 382_llama3_30_1_0.0_0.0
# Skipping test 383_llama3_30_1_0.0_0.0
# Skipping test 384_llama3_30_1_0.0_0.0
# Skipping test 385_llama3_30_1_0.0_0.0
# Skipping test 386_llama3_30_1_0.0_0.0
# Skipping test 387_llama3_30_1_0.0_0.0
# Skipping test 388_llama3_30_1_0.0_0.0
# Skipping test 389_llama3_30_1_0.0_0.0
# Skipping test 390_llama3_30_1_0.0_0.0
# Skipping test 391_llama3_30_1_0.0_0.0
# Skipping test 392_llama3_30_1_0.0_0.0
# Skipping test 393_llama3_30_1_0.0_0.0
# Skipping test 394_llama3_30_1_0.0_0.0
# Skipping test 395_llama3_30_1_0.0_0.0
# Skipping test 396_llama3_30_1_0.0_0.0
# Skipping test 397_llama3_30_1_0.0_0.0
# Skipping test 398_llama3_30_1_0.0_0.0
# Skipping test 399_llama3_30_1_0.0_0.0
# Skipping test 400_llama3_30_1_0.0_0.0
# Skipping test 401_llama3_30_1_0.0_0.0
# Skipping test 402_llama3_30_1_0.0_0.0
# Skipping test 403_llama3_30_1_0.0_0.0
# Skipping test 404_llama3_30_1_0.0_0.0
# Skipping test 405_llama3_30_1_0.0_0.0
# Skipping test 406_llama3_30_1_0.0_0.0
# Skipping test 407_llama3_30_1_0.0_0.0
# Skipping test 408_llama3_30_1_0.0_0.0
# Skipping test 409_llama3_30_1_0.0_0.0
# Skipping test 410_llama3_30_1_0.0_0.0
# Skipping test 411_llama3_30_1_0.0_0.0
# Skipping test 412_llama3_30_1_0.0_0.0
# Skipping test 413_llama3_30_1_0.0_0.0
# Skipping test 414_llama3_30_1_0.0_0.0
# Skipping test 415_llama3_30_1_0.0_0.0
# Skipping test 416_llama3_30_1_0.0_0.0
# Skipping test 417_llama3_30_1_0.0_0.0
# Skipping test 418_llama3_30_1_0.0_0.0
# Skipping test 419_llama3_30_1_0.0_0.0
# Skipping test 420_llama3_30_1_0.0_0.0
# Skipping test 421_llama3_30_1_0.0_0.0
# Skipping test 422_llama3_30_1_0.0_0.0
# Skipping test 423_llama3_30_1_0.0_0.0
# Skipping test 424_llama3_30_1_0.0_0.0
# Skipping test 425_llama3_30_1_0.0_0.0
# Skipping test 426_llama3_30_1_0.0_0.0
# Skipping test 427_llama3_30_1_0.0_0.0
# Skipping test 428_llama3_30_1_0.0_0.0
# Skipping test 429_llama3_30_1_0.0_0.0
# Skipping test 430_llama3_30_1_0.0_0.0
# Skipping test 431_llama3_30_1_0.0_0.0
# Skipping test 432_llama3_30_1_0.0_0.0
# Skipping test 433_llama3_30_1_0.0_0.0
# Skipping test 434_llama3_30_1_0.0_0.0
# Skipping test 435_llama3_30_1_0.0_0.0
# Skipping test 436_llama3_30_1_0.0_0.0
# Skipping test 437_llama3_30_1_0.0_0.0
# Skipping test 438_llama3_30_1_0.0_0.0
# Skipping test 439_llama3_30_1_0.0_0.0
# Skipping test 440_llama3_30_1_0.0_0.0
# Skipping test 441_llama3_30_1_0.0_0.0
# Skipping test 442_llama3_30_1_0.0_0.0
# Skipping test 443_llama3_30_1_0.0_0.0
# Skipping test 444_llama3_30_1_0.0_0.0
# Skipping test 445_llama3_30_1_0.0_0.0
# Skipping test 446_llama3_30_1_0.0_0.0
# Skipping test 447_llama3_30_1_0.0_0.0
# Skipping test 448_llama3_30_1_0.0_0.0
# Skipping test 449_llama3_30_1_0.0_0.0
# Skipping test 450_llama3_30_1_0.0_0.0
# Skipping test 451_llama3_30_1_0.0_0.0
# Skipping test 452_llama3_30_1_0.0_0.0
# Skipping test 453_llama3_30_1_0.0_0.0
# Skipping test 454_llama3_30_1_0.0_0.0
# Skipping test 455_llama3_30_1_0.0_0.0
# Skipping test 456_llama3_30_1_0.0_0.0
# Skipping test 457_llama3_30_1_0.0_0.0
# Skipping test 458_llama3_30_1_0.0_0.0
# Skipping test 459_llama3_30_1_0.0_0.0
# Skipping test 460_llama3_30_1_0.0_0.0
# Skipping test 461_llama3_30_1_0.0_0.0
# Skipping test 462_llama3_30_1_0.0_0.0
# Skipping test 463_llama3_30_1_0.0_0.0
# Skipping test 464_llama3_30_1_0.0_0.0
# Skipping test 465_llama3_30_1_0.0_0.0
# Skipping test 466_llama3_30_1_0.0_0.0
# Skipping test 467_llama3_30_1_0.0_0.0
# Skipping test 468_llama3_30_1_0.0_0.0
# Skipping test 469_llama3_30_1_0.0_0.0
# Skipping test 470_llama3_30_1_0.0_0.0
# Skipping test 471_llama3_30_1_0.0_0.0
# Skipping test 472_llama3_30_1_0.0_0.0
# Skipping test 473_llama3_30_1_0.0_0.0
# Skipping test 474_llama3_30_1_0.0_0.0
# Skipping test 475_llama3_30_1_0.0_0.0
# Skipping test 476_llama3_30_1_0.0_0.0
# Skipping test 477_llama3_30_1_0.0_0.0
# Skipping test 478_llama3_30_1_0.0_0.0
# Skipping test 479_llama3_30_1_0.0_0.0
# Skipping test 480_llama3_30_1_0.0_0.0
# Skipping test 481_llama3_30_1_0.0_0.0
# Skipping test 482_llama3_30_1_0.0_0.0
# Skipping test 483_llama3_30_1_0.0_0.0
# Skipping test 484_llama3_30_1_0.0_0.0
# Skipping test 485_llama3_30_1_0.0_0.0
# Skipping test 486_llama3_30_1_0.0_0.0
# Skipping test 487_llama3_30_1_0.0_0.0
# Skipping test 488_llama3_30_1_0.0_0.0
# Skipping test 489_llama3_30_1_0.0_0.0
# Skipping test 490_llama3_30_1_0.0_0.0
# Skipping test 491_llama3_30_1_0.0_0.0
# Skipping test 492_llama3_30_1_0.0_0.0
# Skipping test 493_llama3_30_1_0.0_0.0
# Skipping test 494_llama3_30_1_0.0_0.0
# Skipping test 495_llama3_30_1_0.0_0.0
# Skipping test 496_llama3_30_1_0.0_0.0
# Skipping test 497_llama3_30_1_0.0_0.0
# Skipping test 498_llama3_30_1_0.0_0.0
# Skipping test 499_llama3_30_1_0.0_0.0
# Skipping test 500_llama3_30_1_0.0_0.0
# Skipping test 501_llama3_30_1_0.0_0.0
# Skipping test 502_llama3_30_1_0.0_0.0
# Skipping test 503_llama3_30_1_0.0_0.0
# Skipping test 504_llama3_30_1_0.0_0.0
# Skipping test 505_llama3_30_1_0.0_0.0
# Skipping test 506_llama3_30_1_0.0_0.0
# Skipping test 507_llama3_30_1_0.0_0.0
# Skipping test 508_llama3_30_1_0.0_0.0
# Skipping test 509_llama3_30_1_0.0_0.0
# Skipping test 510_llama3_30_1_0.0_0.0
# Skipping test 511_llama3_30_1_0.0_0.0
# Skipping test 512_llama3_30_1_0.0_0.0
# Skipping test 513_llama3_30_1_0.0_0.0
# Skipping test 514_llama3_30_1_0.0_0.0
# Skipping test 515_llama3_30_1_0.0_0.0
# Skipping test 516_llama3_30_1_0.0_0.0
# Skipping test 517_llama3_30_1_0.0_0.0
# Skipping test 518_llama3_30_1_0.0_0.0
# Skipping test 519_llama3_30_1_0.0_0.0
# Skipping test 520_llama3_30_1_0.0_0.0
# Skipping test 521_llama3_30_1_0.0_0.0
# Skipping test 522_llama3_30_1_0.0_0.0
# Skipping test 523_llama3_30_1_0.0_0.0
# Skipping test 524_llama3_30_1_0.0_0.0
# Skipping test 525_llama3_30_1_0.0_0.0
# Skipping test 526_llama3_30_1_0.0_0.0
# Skipping test 527_llama3_30_1_0.0_0.0
# Skipping test 528_llama3_30_1_0.0_0.0
# Skipping test 529_llama3_30_1_0.0_0.0
# Skipping test 530_llama3_30_1_0.0_0.0
# Skipping test 531_llama3_30_1_0.0_0.0
# Skipping test 532_llama3_30_1_0.0_0.0
# Skipping test 533_llama3_30_1_0.0_0.0
# Skipping test 534_llama3_30_1_0.0_0.0
# Skipping test 535_llama3_30_1_0.0_0.0
# Skipping test 536_llama3_30_1_0.0_0.0
# Skipping test 537_llama3_30_1_0.0_0.0
# Skipping test 538_llama3_30_1_0.0_0.0
# Skipping test 539_llama3_30_1_0.0_0.0
# Skipping test 540_llama3_30_1_0.0_0.0
# Skipping test 541_llama3_30_1_0.0_0.0
# Skipping test 542_llama3_30_1_0.0_0.0
# Skipping test 543_llama3_30_1_0.0_0.0
# Skipping test 544_llama3_30_1_0.0_0.0
# Skipping test 545_llama3_30_1_0.0_0.0
# Skipping test 546_llama3_30_1_0.0_0.0
# Skipping test 547_llama3_30_1_0.0_0.0
# Skipping test 548_llama3_30_1_0.0_0.0
# Skipping test 549_llama3_30_1_0.0_0.0
# Skipping test 550_llama3_30_1_0.0_0.0
# Skipping test 551_llama3_30_1_0.0_0.0
# Skipping test 552_llama3_30_1_0.0_0.0
# Skipping test 553_llama3_30_1_0.0_0.0
# Skipping test 554_llama3_30_1_0.0_0.0
# Skipping test 555_llama3_30_1_0.0_0.0
# Skipping test 556_llama3_30_1_0.0_0.0
# Skipping test 557_llama3_30_1_0.0_0.0
# Skipping test 558_llama3_30_1_0.0_0.0
# Skipping test 559_llama3_30_1_0.0_0.0
# Skipping test 560_llama3_30_1_0.0_0.0
# Skipping test 561_llama3_30_1_0.0_0.0
# Skipping test 562_llama3_30_1_0.0_0.0
# Skipping test 563_llama3_30_1_0.0_0.0
# Skipping test 564_llama3_30_1_0.0_0.0
# Skipping test 565_llama3_30_1_0.0_0.0
# Skipping test 566_llama3_30_1_0.0_0.0
# Skipping test 567_llama3_30_1_0.0_0.0
# Skipping test 568_llama3_30_1_0.0_0.0
# Skipping test 569_llama3_30_1_0.0_0.0
# Skipping test 570_llama3_30_1_0.0_0.0
# Skipping test 571_llama3_30_1_0.0_0.0
# Skipping test 572_llama3_30_1_0.0_0.0
# Skipping test 573_llama3_30_1_0.0_0.0
# Skipping test 574_llama3_30_1_0.0_0.0
# Skipping test 575_llama3_30_1_0.0_0.0
# Skipping test 576_llama3_30_1_0.0_0.0
# Skipping test 577_llama3_30_1_0.0_0.0
# Skipping test 578_llama3_30_1_0.0_0.0
# Skipping test 579_llama3_30_1_0.0_0.0
# Skipping test 580_llama3_30_1_0.0_0.0
# Skipping test 581_llama3_30_1_0.0_0.0
# Skipping test 582_llama3_30_1_0.0_0.0
# Skipping test 583_llama3_30_1_0.0_0.0
# Skipping test 584_llama3_30_1_0.0_0.0
# Skipping test 585_llama3_30_1_0.0_0.0
# Skipping test 586_llama3_30_1_0.0_0.0
# Skipping test 587_llama3_30_1_0.0_0.0
# Skipping test 588_llama3_30_1_0.0_0.0
# Skipping test 589_llama3_30_1_0.0_0.0
# Skipping test 590_llama3_30_1_0.0_0.0
# Skipping test 591_llama3_30_1_0.0_0.0
# Skipping test 592_llama3_30_1_0.0_0.0
# Skipping test 593_llama3_30_1_0.0_0.0
# Skipping test 594_llama3_30_1_0.0_0.0
# Skipping test 595_llama3_30_1_0.0_0.0
# Skipping test 596_llama3_30_1_0.0_0.0
# Skipping test 597_llama3_30_1_0.0_0.0
# Skipping test 598_llama3_30_1_0.0_0.0
# Skipping test 599_llama3_30_1_0.0_0.0
# Skipping test 600_llama3_30_1_0.0_0.0
# Skipping test 601_llama3_30_1_0.0_0.0
# Skipping test 602_llama3_30_1_0.0_0.0
# Skipping test 603_llama3_30_1_0.0_0.0
# Skipping test 604_llama3_30_1_0.0_0.0
# Skipping test 605_llama3_30_1_0.0_0.0
# Skipping test 606_llama3_30_1_0.0_0.0
# Skipping test 607_llama3_30_1_0.0_0.0
# Skipping test 608_llama3_30_1_0.0_0.0
# Skipping test 609_llama3_30_1_0.0_0.0
# Skipping test 610_llama3_30_1_0.0_0.0
# Skipping test 611_llama3_30_1_0.0_0.0
# Skipping test 612_llama3_30_1_0.0_0.0
# Skipping test 613_llama3_30_1_0.0_0.0
# Skipping test 614_llama3_30_1_0.0_0.0
# Skipping test 615_llama3_30_1_0.0_0.0
# Skipping test 616_llama3_30_1_0.0_0.0
# Skipping test 617_llama3_30_1_0.0_0.0
# Skipping test 618_llama3_30_1_0.0_0.0
# Skipping test 619_llama3_30_1_0.0_0.0
# Skipping test 620_llama3_30_1_0.0_0.0
# Skipping test 621_llama3_30_1_0.0_0.0
# Skipping test 622_llama3_30_1_0.0_0.0
# Skipping test 623_llama3_30_1_0.0_0.0
# Skipping test 624_llama3_30_1_0.0_0.0
# Skipping test 625_llama3_30_1_0.0_0.0
# Skipping test 626_llama3_30_1_0.0_0.0
# Skipping test 627_llama3_30_1_0.0_0.0
# Skipping test 628_llama3_30_1_0.0_0.0
# Skipping test 629_llama3_30_1_0.0_0.0
# Skipping test 630_llama3_30_1_0.0_0.0
# Skipping test 631_llama3_30_1_0.0_0.0
# Skipping test 632_llama3_30_1_0.0_0.0
# Skipping test 633_llama3_30_1_0.0_0.0
# Skipping test 634_llama3_30_1_0.0_0.0
# Skipping test 635_llama3_30_1_0.0_0.0
# Skipping test 636_llama3_30_1_0.0_0.0
# Skipping test 637_llama3_30_1_0.0_0.0
# Skipping test 638_llama3_30_1_0.0_0.0
# Skipping test 639_llama3_30_1_0.0_0.0
# Skipping test 640_llama3_30_1_0.0_0.0
# Skipping test 641_llama3_30_1_0.0_0.0
# Skipping test 642_llama3_30_1_0.0_0.0
# Skipping test 643_llama3_30_1_0.0_0.0
# Skipping test 644_llama3_30_1_0.0_0.0
# Skipping test 645_llama3_30_1_0.0_0.0
# Skipping test 646_llama3_30_1_0.0_0.0
# Skipping test 647_llama3_30_1_0.0_0.0
# Skipping test 648_llama3_30_1_0.0_0.0
# Skipping test 649_llama3_30_1_0.0_0.0
# Skipping test 650_llama3_30_1_0.0_0.0
# Skipping test 651_llama3_30_1_0.0_0.0
# Skipping test 652_llama3_30_1_0.0_0.0
# Skipping test 653_llama3_30_1_0.0_0.0
# Skipping test 654_llama3_30_1_0.0_0.0
# Skipping test 655_llama3_30_1_0.0_0.0
# Skipping test 656_llama3_30_1_0.0_0.0
# Skipping test 657_llama3_30_1_0.0_0.0
# Skipping test 658_llama3_30_1_0.0_0.0
# Skipping test 659_llama3_30_1_0.0_0.0
# Skipping test 660_llama3_30_1_0.0_0.0
# Skipping test 661_llama3_30_1_0.0_0.0
# Skipping test 662_llama3_30_1_0.0_0.0
# Skipping test 663_llama3_30_1_0.0_0.0
# Skipping test 664_llama3_30_1_0.0_0.0
# Skipping test 665_llama3_30_1_0.0_0.0
# Skipping test 666_llama3_30_1_0.0_0.0
# Skipping test 667_llama3_30_1_0.0_0.0
# Skipping test 668_llama3_30_1_0.0_0.0
# Skipping test 669_llama3_30_1_0.0_0.0
# Skipping test 670_llama3_30_1_0.0_0.0
# Skipping test 671_llama3_30_1_0.0_0.0
# Skipping test 672_llama3_30_1_0.0_0.0
# Skipping test 673_llama3_30_1_0.0_0.0
# Skipping test 674_llama3_30_1_0.0_0.0
# Skipping test 675_llama3_30_1_0.0_0.0
# Skipping test 676_llama3_30_1_0.0_0.0
# Skipping test 677_llama3_30_1_0.0_0.0
# Skipping test 678_llama3_30_1_0.0_0.0
# Skipping test 679_llama3_30_1_0.0_0.0
# Skipping test 680_llama3_30_1_0.0_0.0
# Skipping test 681_llama3_30_1_0.0_0.0
# Skipping test 682_llama3_30_1_0.0_0.0
# Skipping test 683_llama3_30_1_0.0_0.0
# Skipping test 684_llama3_30_1_0.0_0.0
# Skipping test 685_llama3_30_1_0.0_0.0
# Skipping test 686_llama3_30_1_0.0_0.0
# Skipping test 687_llama3_30_1_0.0_0.0
# Skipping test 688_llama3_30_1_0.0_0.0
# Skipping test 689_llama3_30_1_0.0_0.0
# Skipping test 690_llama3_30_1_0.0_0.0
# Skipping test 691_llama3_30_1_0.0_0.0
# Skipping test 692_llama3_30_1_0.0_0.0
# Skipping test 693_llama3_30_1_0.0_0.0
# Skipping test 694_llama3_30_1_0.0_0.0
# Skipping test 695_llama3_30_1_0.0_0.0
# Skipping test 696_llama3_30_1_0.0_0.0
# Skipping test 697_llama3_30_1_0.0_0.0
# Skipping test 698_llama3_30_1_0.0_0.0
# Skipping test 699_llama3_30_1_0.0_0.0
# Skipping test 700_llama3_30_1_0.0_0.0
# Skipping test 701_llama3_30_1_0.0_0.0
# Skipping test 702_llama3_30_1_0.0_0.0
# Skipping test 703_llama3_30_1_0.0_0.0
# Skipping test 704_llama3_30_1_0.0_0.0
# Skipping test 705_llama3_30_1_0.0_0.0
# Skipping test 706_llama3_30_1_0.0_0.0
# Skipping test 707_llama3_30_1_0.0_0.0
# Skipping test 708_llama3_30_1_0.0_0.0
# Skipping test 709_llama3_30_1_0.0_0.0
# Skipping test 710_llama3_30_1_0.0_0.0
# Skipping test 711_llama3_30_1_0.0_0.0
# Skipping test 712_llama3_30_1_0.0_0.0
# Skipping test 713_llama3_30_1_0.0_0.0
# Skipping test 714_llama3_30_1_0.0_0.0
# Skipping test 715_llama3_30_1_0.0_0.0
# Skipping test 716_llama3_30_1_0.0_0.0
# Skipping test 717_llama3_30_1_0.0_0.0
# Skipping test 718_llama3_30_1_0.0_0.0
# Skipping test 719_llama3_30_1_0.0_0.0
# Skipping test 720_llama3_30_1_0.0_0.0
# Skipping test 721_llama3_30_1_0.0_0.0
# Skipping test 722_llama3_30_1_0.0_0.0
# Skipping test 723_llama3_30_1_0.0_0.0
# Skipping test 724_llama3_30_1_0.0_0.0
# Skipping test 725_llama3_30_1_0.0_0.0
# Skipping test 726_llama3_30_1_0.0_0.0
# Skipping test 727_llama3_30_1_0.0_0.0
# Skipping test 728_llama3_30_1_0.0_0.0
# Skipping test 729_llama3_30_1_0.0_0.0
# Skipping test 730_llama3_30_1_0.0_0.0
# Skipping test 731_llama3_30_1_0.0_0.0
# Skipping test 732_llama3_30_1_0.0_0.0
# Skipping test 733_llama3_30_1_0.0_0.0
# Skipping test 734_llama3_30_1_0.0_0.0
# Skipping test 735_llama3_30_1_0.0_0.0
# Skipping test 736_llama3_30_1_0.0_0.0
# Skipping test 737_llama3_30_1_0.0_0.0
# Skipping test 738_llama3_30_1_0.0_0.0
# Skipping test 739_llama3_30_1_0.0_0.0
# Skipping test 740_llama3_30_1_0.0_0.0
# Skipping test 741_llama3_30_1_0.0_0.0
# Skipping test 742_llama3_30_1_0.0_0.0
# Skipping test 743_llama3_30_1_0.0_0.0
# Skipping test 744_llama3_30_1_0.0_0.0
# Skipping test 745_llama3_30_1_0.0_0.0
# Skipping test 746_llama3_30_1_0.0_0.0
# Skipping test 747_llama3_30_1_0.0_0.0
# Skipping test 748_llama3_30_1_0.0_0.0
# Skipping test 749_llama3_30_1_0.0_0.0
# Skipping test 750_llama3_30_1_0.0_0.0
# Skipping test 751_llama3_30_1_0.0_0.0
# Skipping test 752_llama3_30_1_0.0_0.0
# Skipping test 753_llama3_30_1_0.0_0.0
# Skipping test 754_llama3_30_1_0.0_0.0
# Skipping test 755_llama3_30_1_0.0_0.0
# Skipping test 756_llama3_30_1_0.0_0.0
# Skipping test 757_llama3_30_1_0.0_0.0
# Skipping test 758_llama3_30_1_0.0_0.0
# Skipping test 759_llama3_30_1_0.0_0.0
# Skipping test 760_llama3_30_1_0.0_0.0
# Skipping test 761_llama3_30_1_0.0_0.0
# Skipping test 762_llama3_30_1_0.0_0.0
# Skipping test 763_llama3_30_1_0.0_0.0
# Skipping test 764_llama3_30_1_0.0_0.0
# Skipping test 765_llama3_30_1_0.0_0.0
# Skipping test 766_llama3_30_1_0.0_0.0
# Skipping test 767_llama3_30_1_0.0_0.0
# Skipping test 768_llama3_30_1_0.0_0.0
# Skipping test 769_llama3_30_1_0.0_0.0
# Skipping test 770_llama3_30_1_0.0_0.0
# Skipping test 771_llama3_30_1_0.0_0.0
# Skipping test 772_llama3_30_1_0.0_0.0
# Skipping test 773_llama3_30_1_0.0_0.0
# Skipping test 774_llama3_30_1_0.0_0.0
# Skipping test 775_llama3_30_1_0.0_0.0
# Skipping test 776_llama3_30_1_0.0_0.0
# Skipping test 777_llama3_30_1_0.0_0.0
# Skipping test 778_llama3_30_1_0.0_0.0
# Skipping test 779_llama3_30_1_0.0_0.0
# Skipping test 780_llama3_30_1_0.0_0.0
# Skipping test 781_llama3_30_1_0.0_0.0
# Skipping test 782_llama3_30_1_0.0_0.0
# Skipping test 783_llama3_30_1_0.0_0.0
# Skipping test 784_llama3_30_1_0.0_0.0
# Skipping test 785_llama3_30_1_0.0_0.0
# Skipping test 786_llama3_30_1_0.0_0.0
# Skipping test 787_llama3_30_1_0.0_0.0
# Skipping test 788_llama3_30_1_0.0_0.0
# Skipping test 789_llama3_30_1_0.0_0.0
# Skipping test 790_llama3_30_1_0.0_0.0
# Skipping test 791_llama3_30_1_0.0_0.0
# Skipping test 792_llama3_30_1_0.0_0.0
# Skipping test 793_llama3_30_1_0.0_0.0
# Skipping test 794_llama3_30_1_0.0_0.0
# Skipping test 795_llama3_30_1_0.0_0.0
# Skipping test 796_llama3_30_1_0.0_0.0
# Skipping test 797_llama3_30_1_0.0_0.0
# Skipping test 798_llama3_30_1_0.0_0.0
# Skipping test 799_llama3_30_1_0.0_0.0
# Skipping test 800_llama3_30_1_0.0_0.0
# Skipping test 801_llama3_30_1_0.0_0.0
# Skipping test 802_llama3_30_1_0.0_0.0
# Skipping test 803_llama3_30_1_0.0_0.0
# Skipping test 804_llama3_30_1_0.0_0.0
# Skipping test 805_llama3_30_1_0.0_0.0
# Skipping test 806_llama3_30_1_0.0_0.0
# Skipping test 807_llama3_30_1_0.0_0.0
# Skipping test 808_llama3_30_1_0.0_0.0
# Skipping test 809_llama3_30_1_0.0_0.0
# Skipping test 810_llama3_30_1_0.0_0.0
# Skipping test 811_llama3_30_1_0.0_0.0
# Skipping test 812_llama3_30_1_0.0_0.0
# Skipping test 813_llama3_30_1_0.0_0.0
# Skipping test 814_llama3_30_1_0.0_0.0
# Skipping test 815_llama3_30_1_0.0_0.0
# Skipping test 816_llama3_30_1_0.0_0.0
# Skipping test 817_llama3_30_1_0.0_0.0
# Skipping test 818_llama3_30_1_0.0_0.0
# Skipping test 819_llama3_30_1_0.0_0.0
# Skipping test 820_llama3_30_1_0.0_0.0
# Skipping test 821_llama3_30_1_0.0_0.0
# Skipping test 822_llama3_30_1_0.0_0.0
# Skipping test 823_llama3_30_1_0.0_0.0
# Skipping test 824_llama3_30_1_0.0_0.0
# Skipping test 825_llama3_30_1_0.0_0.0
# Skipping test 826_llama3_30_1_0.0_0.0
# Skipping test 827_llama3_30_1_0.0_0.0
# Skipping test 828_llama3_30_1_0.0_0.0
# Skipping test 829_llama3_30_1_0.0_0.0
# Skipping test 830_llama3_30_1_0.0_0.0
# Skipping test 831_llama3_30_1_0.0_0.0
# Skipping test 832_llama3_30_1_0.0_0.0
# Skipping test 833_llama3_30_1_0.0_0.0
# Skipping test 834_llama3_30_1_0.0_0.0
# Skipping test 835_llama3_30_1_0.0_0.0
# Skipping test 836_llama3_30_1_0.0_0.0
# Skipping test 837_llama3_30_1_0.0_0.0
# Skipping test 838_llama3_30_1_0.0_0.0
# Skipping test 839_llama3_30_1_0.0_0.0
# Skipping test 840_llama3_30_1_0.0_0.0
# Skipping test 841_llama3_30_1_0.0_0.0
# Skipping test 842_llama3_30_1_0.0_0.0
# Skipping test 843_llama3_30_1_0.0_0.0
# Skipping test 844_llama3_30_1_0.0_0.0
# Skipping test 845_llama3_30_1_0.0_0.0
# Skipping test 846_llama3_30_1_0.0_0.0
# Skipping test 847_llama3_30_1_0.0_0.0
# Skipping test 848_llama3_30_1_0.0_0.0
# Skipping test 849_llama3_30_1_0.0_0.0
# Skipping test 850_llama3_30_1_0.0_0.0
# Skipping test 851_llama3_30_1_0.0_0.0
# Skipping test 852_llama3_30_1_0.0_0.0
# Skipping test 853_llama3_30_1_0.0_0.0
# Skipping test 854_llama3_30_1_0.0_0.0
# Skipping test 855_llama3_30_1_0.0_0.0
# Skipping test 856_llama3_30_1_0.0_0.0
# Skipping test 857_llama3_30_1_0.0_0.0
# Skipping test 858_llama3_30_1_0.0_0.0
# Skipping test 859_llama3_30_1_0.0_0.0
# Skipping test 860_llama3_30_1_0.0_0.0
# Skipping test 861_llama3_30_1_0.0_0.0
# Skipping test 862_llama3_30_1_0.0_0.0
# Skipping test 863_llama3_30_1_0.0_0.0
# Skipping test 864_llama3_30_1_0.0_0.0
# Skipping test 865_llama3_30_1_0.0_0.0
# Skipping test 866_llama3_30_1_0.0_0.0
# Skipping test 867_llama3_30_1_0.0_0.0
# Skipping test 868_llama3_30_1_0.0_0.0
# Skipping test 869_llama3_30_1_0.0_0.0
# Skipping test 870_llama3_30_1_0.0_0.0
# Skipping test 871_llama3_30_1_0.0_0.0
# Skipping test 872_llama3_30_1_0.0_0.0
# Skipping test 873_llama3_30_1_0.0_0.0
# Skipping test 874_llama3_30_1_0.0_0.0
# Skipping test 875_llama3_30_1_0.0_0.0
# Skipping test 876_llama3_30_1_0.0_0.0
# Skipping test 877_llama3_30_1_0.0_0.0
# Skipping test 878_llama3_30_1_0.0_0.0
# Skipping test 879_llama3_30_1_0.0_0.0
# Skipping test 880_llama3_30_1_0.0_0.0
# Skipping test 881_llama3_30_1_0.0_0.0
# Skipping test 882_llama3_30_1_0.0_0.0
# Skipping test 883_llama3_30_1_0.0_0.0
# Skipping test 884_llama3_30_1_0.0_0.0
# Skipping test 885_llama3_30_1_0.0_0.0
# Skipping test 886_llama3_30_1_0.0_0.0
# Skipping test 887_llama3_30_1_0.0_0.0
# Skipping test 888_llama3_30_1_0.0_0.0
# Skipping test 889_llama3_30_1_0.0_0.0
# Skipping test 890_llama3_30_1_0.0_0.0
# Skipping test 891_llama3_30_1_0.0_0.0
# Skipping test 892_llama3_30_1_0.0_0.0
# Skipping test 893_llama3_30_1_0.0_0.0
# Skipping test 894_llama3_30_1_0.0_0.0
# Skipping test 895_llama3_30_1_0.0_0.0
# Skipping test 896_llama3_30_1_0.0_0.0
# Skipping test 897_llama3_30_1_0.0_0.0
# Skipping test 898_llama3_30_1_0.0_0.0
# Skipping test 899_llama3_30_1_0.0_0.0
# Skipping test 900_llama3_30_1_0.0_0.0
# Skipping test 901_llama3_30_1_0.0_0.0
# Skipping test 902_llama3_30_1_0.0_0.0
# Skipping test 903_llama3_30_1_0.0_0.0
# Skipping test 904_llama3_30_1_0.0_0.0
# Skipping test 905_llama3_30_1_0.0_0.0
# Skipping test 906_llama3_30_1_0.0_0.0
# Skipping test 907_llama3_30_1_0.0_0.0
# Skipping test 908_llama3_30_1_0.0_0.0
# Skipping test 909_llama3_30_1_0.0_0.0
# Skipping test 910_llama3_30_1_0.0_0.0
# Skipping test 911_llama3_30_1_0.0_0.0
# Skipping test 912_llama3_30_1_0.0_0.0
# Skipping test 913_llama3_30_1_0.0_0.0
# Skipping test 914_llama3_30_1_0.0_0.0
# Skipping test 915_llama3_30_1_0.0_0.0
# Skipping test 916_llama3_30_1_0.0_0.0
# Skipping test 917_llama3_30_1_0.0_0.0
# Skipping test 918_llama3_30_1_0.0_0.0
# Skipping test 919_llama3_30_1_0.0_0.0
# Skipping test 920_llama3_30_1_0.0_0.0
# Skipping test 921_llama3_30_1_0.0_0.0
# Skipping test 922_llama3_30_1_0.0_0.0
# Skipping test 923_llama3_30_1_0.0_0.0
# Skipping test 924_llama3_30_1_0.0_0.0
# Skipping test 925_llama3_30_1_0.0_0.0
# Skipping test 926_llama3_30_1_0.0_0.0
# Skipping test 927_llama3_30_1_0.0_0.0
# Skipping test 928_llama3_30_1_0.0_0.0
# Skipping test 929_llama3_30_1_0.0_0.0
# Skipping test 930_llama3_30_1_0.0_0.0
# Skipping test 931_llama3_30_1_0.0_0.0
# Skipping test 932_llama3_30_1_0.0_0.0
# Skipping test 933_llama3_30_1_0.0_0.0
# Skipping test 934_llama3_30_1_0.0_0.0
# Skipping test 935_llama3_30_1_0.0_0.0
# Skipping test 936_llama3_30_1_0.0_0.0
# Skipping test 937_llama3_30_1_0.0_0.0
# Skipping test 938_llama3_30_1_0.0_0.0
# Skipping test 939_llama3_30_1_0.0_0.0
# Skipping test 940_llama3_30_1_0.0_0.0
# Skipping test 941_llama3_30_1_0.0_0.0
# Skipping test 942_llama3_30_1_0.0_0.0
# Skipping test 943_llama3_30_1_0.0_0.0
# Skipping test 944_llama3_30_1_0.0_0.0
# Skipping test 945_llama3_30_1_0.0_0.0
# Skipping test 946_llama3_30_1_0.0_0.0
# Skipping test 947_llama3_30_1_0.0_0.0
# Skipping test 948_llama3_30_1_0.0_0.0
# Skipping test 949_llama3_30_1_0.0_0.0
# Skipping test 950_llama3_30_1_0.0_0.0
# Skipping test 951_llama3_30_1_0.0_0.0
# Skipping test 952_llama3_30_1_0.0_0.0
# Skipping test 953_llama3_30_1_0.0_0.0
# Skipping test 954_llama3_30_1_0.0_0.0
# Skipping test 955_llama3_30_1_0.0_0.0
# Skipping test 956_llama3_30_1_0.0_0.0
# Skipping test 957_llama3_30_1_0.0_0.0
# Skipping test 958_llama3_30_1_0.0_0.0
# Skipping test 959_llama3_30_1_0.0_0.0
# Skipping test 960_llama3_30_1_0.0_0.0
# Skipping test 961_llama3_30_1_0.0_0.0
# Skipping test 962_llama3_30_1_0.0_0.0
# Skipping test 963_llama3_30_1_0.0_0.0
# Skipping test 964_llama3_30_1_0.0_0.0
# Skipping test 965_llama3_30_1_0.0_0.0
# Skipping test 966_llama3_30_1_0.0_0.0
# Skipping test 967_llama3_30_1_0.0_0.0
# Skipping test 968_llama3_30_1_0.0_0.0
# Skipping test 969_llama3_30_1_0.0_0.0
# Skipping test 970_llama3_30_1_0.0_0.0
# Skipping test 971_llama3_30_1_0.0_0.0
# Skipping test 972_llama3_30_1_0.0_0.0
# Skipping test 973_llama3_30_1_0.0_0.0
# Skipping test 974_llama3_30_1_0.0_0.0
# Skipping test 975_llama3_30_1_0.0_0.0
# Skipping test 976_llama3_30_1_0.0_0.0
# Skipping test 977_llama3_30_1_0.0_0.0
# Skipping test 978_llama3_30_1_0.0_0.0
# Skipping test 979_llama3_30_1_0.0_0.0
# Skipping test 980_llama3_30_1_0.0_0.0
# Skipping test 981_llama3_30_1_0.0_0.0
# Skipping test 982_llama3_30_1_0.0_0.0
# Skipping test 983_llama3_30_1_0.0_0.0
# Skipping test 984_llama3_30_1_0.0_0.0
# Skipping test 985_llama3_30_1_0.0_0.0
# Skipping test 986_llama3_30_1_0.0_0.0
# Skipping test 987_llama3_30_1_0.0_0.0
# Skipping test 988_llama3_30_1_0.0_0.0
# Skipping test 989_llama3_30_1_0.0_0.0
# Skipping test 990_llama3_30_1_0.0_0.0
# Skipping test 991_llama3_30_1_0.0_0.0
# Skipping test 992_llama3_30_1_0.0_0.0
# Skipping test 993_llama3_30_1_0.0_0.0
# Skipping test 994_llama3_30_1_0.0_0.0
# Skipping test 995_llama3_30_1_0.0_0.0
# Skipping test 996_llama3_30_1_0.0_0.0
# Skipping test 997_llama3_30_1_0.0_0.0
# Skipping test 998_llama3_30_1_0.0_0.0
# Skipping test 999_llama3_30_1_0.0_0.0
# Skipping test 1000_llama3_30_1_0.0_0.0
# Skipping test 1001_llama3_30_1_0.0_0.0
# Skipping test 1002_llama3_30_1_0.0_0.0
# Skipping test 1003_llama3_30_1_0.0_0.0
# Skipping test 1004_llama3_30_1_0.0_0.0
# Skipping test 1005_llama3_30_1_0.0_0.0
# Skipping test 1006_llama3_30_1_0.0_0.0
# Skipping test 1007_llama3_30_1_0.0_0.0
# Skipping test 1008_llama3_30_1_0.0_0.0
# Skipping test 1009_llama3_30_1_0.0_0.0
# Skipping test 1010_llama3_30_1_0.0_0.0
# Skipping test 1011_llama3_30_1_0.0_0.0
# Skipping test 1012_llama3_30_1_0.0_0.0
# Skipping test 1013_llama3_30_1_0.0_0.0
# Skipping test 1014_llama3_30_1_0.0_0.0
# Skipping test 1015_llama3_30_1_0.0_0.0
# Skipping test 1016_llama3_30_1_0.0_0.0
# Skipping test 1017_llama3_30_1_0.0_0.0
# Skipping test 1018_llama3_30_1_0.0_0.0
# Skipping test 1019_llama3_30_1_0.0_0.0
# Skipping test 1020_llama3_30_1_0.0_0.0
# Skipping test 1021_llama3_30_1_0.0_0.0
# Skipping test 1022_llama3_30_1_0.0_0.0
# Skipping test 1023_llama3_30_1_0.0_0.0
# Skipping test 1024_llama3_30_1_0.0_0.0
# Skipping test 1025_llama3_30_1_0.0_0.0
# Skipping test 1026_llama3_30_1_0.0_0.0
# Skipping test 1027_llama3_30_1_0.0_0.0
# Skipping test 1028_llama3_30_1_0.0_0.0
# Skipping test 1029_llama3_30_1_0.0_0.0
# Skipping test 1030_llama3_30_1_0.0_0.0
# Skipping test 1031_llama3_30_1_0.0_0.0
# Skipping test 1032_llama3_30_1_0.0_0.0
# Skipping test 1033_llama3_30_1_0.0_0.0
# Skipping test 1034_llama3_30_1_0.0_0.0
# Skipping test 1035_llama3_30_1_0.0_0.0
# Skipping test 1036_llama3_30_1_0.0_0.0
# Skipping test 1037_llama3_30_1_0.0_0.0
# Skipping test 1038_llama3_30_1_0.0_0.0
# Skipping test 1039_llama3_30_1_0.0_0.0
# Skipping test 1040_llama3_30_1_0.0_0.0
# Skipping test 1041_llama3_30_1_0.0_0.0
# Skipping test 1042_llama3_30_1_0.0_0.0
# Skipping test 1043_llama3_30_1_0.0_0.0
# Skipping test 1044_llama3_30_1_0.0_0.0
# Skipping test 1045_llama3_30_1_0.0_0.0
# Skipping test 1046_llama3_30_1_0.0_0.0
# Skipping test 1047_llama3_30_1_0.0_0.0
# Skipping test 1048_llama3_30_1_0.0_0.0
# Skipping test 1049_llama3_30_1_0.0_0.0
# Skipping test 1050_llama3_30_1_0.0_0.0
# Skipping test 1051_llama3_30_1_0.0_0.0
# Skipping test 1052_llama3_30_1_0.0_0.0
# Skipping test 1053_llama3_30_1_0.0_0.0
# Skipping test 1054_llama3_30_1_0.0_0.0
# Skipping test 1055_llama3_30_1_0.0_0.0
# Skipping test 1056_llama3_30_1_0.0_0.0
# Skipping test 1057_llama3_30_1_0.0_0.0
# Skipping test 1058_llama3_30_1_0.0_0.0
# Skipping test 1059_llama3_30_1_0.0_0.0
# Skipping test 1060_llama3_30_1_0.0_0.0
# Skipping test 1061_llama3_30_1_0.0_0.0
# Skipping test 1062_llama3_30_1_0.0_0.0
# Skipping test 1063_llama3_30_1_0.0_0.0
# Skipping test 1064_llama3_30_1_0.0_0.0
# Skipping test 1065_llama3_30_1_0.0_0.0
# Skipping test 1066_llama3_30_1_0.0_0.0
# Skipping test 1067_llama3_30_1_0.0_0.0
# Skipping test 1068_llama3_30_1_0.0_0.0
# Skipping test 1069_llama3_30_1_0.0_0.0
# Skipping test 1070_llama3_30_1_0.0_0.0
# Skipping test 1071_llama3_30_1_0.0_0.0
# Skipping test 1072_llama3_30_1_0.0_0.0
# Skipping test 1073_llama3_30_1_0.0_0.0
# Skipping test 1074_llama3_30_1_0.0_0.0
# Skipping test 1075_llama3_30_1_0.0_0.0
# Skipping test 1076_llama3_30_1_0.0_0.0
# Skipping test 1077_llama3_30_1_0.0_0.0
# Skipping test 1078_llama3_30_1_0.0_0.0
# Skipping test 1079_llama3_30_1_0.0_0.0
# Skipping test 1080_llama3_30_1_0.0_0.0
# Skipping test 1081_llama3_30_1_0.0_0.0
# Skipping test 1082_llama3_30_1_0.0_0.0
# Skipping test 1083_llama3_30_1_0.0_0.0
# Skipping test 1084_llama3_30_1_0.0_0.0
# Skipping test 1085_llama3_30_1_0.0_0.0
# Skipping test 1086_llama3_30_1_0.0_0.0
# Skipping test 1087_llama3_30_1_0.0_0.0
# Skipping test 1088_llama3_30_1_0.0_0.0
# Skipping test 1089_llama3_30_1_0.0_0.0
# Skipping test 1090_llama3_30_1_0.0_0.0
# Skipping test 1091_llama3_30_1_0.0_0.0
# Skipping test 1092_llama3_30_1_0.0_0.0
# Skipping test 1093_llama3_30_1_0.0_0.0
# Skipping test 1094_llama3_30_1_0.0_0.0
# Skipping test 1095_llama3_30_1_0.0_0.0
# Skipping test 1096_llama3_30_1_0.0_0.0
# Skipping test 1097_llama3_30_1_0.0_0.0
# Skipping test 1098_llama3_30_1_0.0_0.0
# Skipping test 1099_llama3_30_1_0.0_0.0
# Skipping test 1100_llama3_30_1_0.0_0.0
# Skipping test 1101_llama3_30_1_0.0_0.0
# Skipping test 1102_llama3_30_1_0.0_0.0
# Skipping test 1103_llama3_30_1_0.0_0.0
# Skipping test 1104_llama3_30_1_0.0_0.0
# Skipping test 1105_llama3_30_1_0.0_0.0
# Skipping test 1106_llama3_30_1_0.0_0.0
# Skipping test 1107_llama3_30_1_0.0_0.0
# Skipping test 1108_llama3_30_1_0.0_0.0
# Skipping test 1109_llama3_30_1_0.0_0.0
# Skipping test 1110_llama3_30_1_0.0_0.0
# Skipping test 1111_llama3_30_1_0.0_0.0
# Skipping test 1112_llama3_30_1_0.0_0.0
# Skipping test 1113_llama3_30_1_0.0_0.0
# Skipping test 1114_llama3_30_1_0.0_0.0
# Skipping test 1115_llama3_30_1_0.0_0.0
# Skipping test 1116_llama3_30_1_0.0_0.0
# Skipping test 1117_llama3_30_1_0.0_0.0
# Skipping test 1118_llama3_30_1_0.0_0.0
# Skipping test 1119_llama3_30_1_0.0_0.0
# Skipping test 1120_llama3_30_1_0.0_0.0
# Skipping test 1121_llama3_30_1_0.0_0.0
# Skipping test 1122_llama3_30_1_0.0_0.0
# Skipping test 1123_llama3_30_1_0.0_0.0
# Skipping test 1124_llama3_30_1_0.0_0.0
# Skipping test 1125_llama3_30_1_0.0_0.0
# Skipping test 1126_llama3_30_1_0.0_0.0
# Skipping test 1127_llama3_30_1_0.0_0.0
# Skipping test 1128_llama3_30_1_0.0_0.0
# Skipping test 1129_llama3_30_1_0.0_0.0
# Skipping test 1130_llama3_30_1_0.0_0.0
# Skipping test 1131_llama3_30_1_0.0_0.0
# Skipping test 1132_llama3_30_1_0.0_0.0
# Skipping test 1133_llama3_30_1_0.0_0.0
# Skipping test 1134_llama3_30_1_0.0_0.0
# Skipping test 1135_llama3_30_1_0.0_0.0
# Skipping test 1136_llama3_30_1_0.0_0.0
# Skipping test 1137_llama3_30_1_0.0_0.0
# Skipping test 1138_llama3_30_1_0.0_0.0
# Skipping test 1139_llama3_30_1_0.0_0.0
# Skipping test 1140_llama3_30_1_0.0_0.0
# Skipping test 1141_llama3_30_1_0.0_0.0
# Skipping test 1142_llama3_30_1_0.0_0.0
# Skipping test 1143_llama3_30_1_0.0_0.0
# Skipping test 1144_llama3_30_1_0.0_0.0
# Skipping test 1145_llama3_30_1_0.0_0.0
# Skipping test 1146_llama3_30_1_0.0_0.0
# Skipping test 1147_llama3_30_1_0.0_0.0
# Skipping test 1148_llama3_30_1_0.0_0.0
# Skipping test 1149_llama3_30_1_0.0_0.0
# Skipping test 1150_llama3_30_1_0.0_0.0
# Skipping test 1151_llama3_30_1_0.0_0.0
# Skipping test 1152_llama3_30_1_0.0_0.0
# Skipping test 1153_llama3_30_1_0.0_0.0
# Skipping test 1154_llama3_30_1_0.0_0.0
# Skipping test 1155_llama3_30_1_0.0_0.0
# Skipping test 1156_llama3_30_1_0.0_0.0
# Skipping test 1157_llama3_30_1_0.0_0.0
# Skipping test 1158_llama3_30_1_0.0_0.0
# Skipping test 1159_llama3_30_1_0.0_0.0
# Skipping test 1160_llama3_30_1_0.0_0.0
# Skipping test 1161_llama3_30_1_0.0_0.0
# Skipping test 1162_llama3_30_1_0.0_0.0
# Skipping test 1163_llama3_30_1_0.0_0.0
# Skipping test 1164_llama3_30_1_0.0_0.0
# Skipping test 1165_llama3_30_1_0.0_0.0
# Skipping test 1166_llama3_30_1_0.0_0.0
# Skipping test 1167_llama3_30_1_0.0_0.0
# Skipping test 1168_llama3_30_1_0.0_0.0
# Skipping test 1169_llama3_30_1_0.0_0.0
# Skipping test 1170_llama3_30_1_0.0_0.0
# Skipping test 1171_llama3_30_1_0.0_0.0
# Skipping test 1172_llama3_30_1_0.0_0.0
# Skipping test 1173_llama3_30_1_0.0_0.0
# Skipping test 1174_llama3_30_1_0.0_0.0
# Skipping test 1175_llama3_30_1_0.0_0.0
# Skipping test 1176_llama3_30_1_0.0_0.0
# Skipping test 1177_llama3_30_1_0.0_0.0
# Skipping test 1178_llama3_30_1_0.0_0.0
# Skipping test 1179_llama3_30_1_0.0_0.0
# Skipping test 1180_llama3_30_1_0.0_0.0
# Skipping test 1181_llama3_30_1_0.0_0.0
# Skipping test 1182_llama3_30_1_0.0_0.0
# Skipping test 1183_llama3_30_1_0.0_0.0
# Skipping test 1184_llama3_30_1_0.0_0.0
# Skipping test 1185_llama3_30_1_0.0_0.0
# Skipping test 1186_llama3_30_1_0.0_0.0
# Skipping test 1187_llama3_30_1_0.0_0.0
# Skipping test 1188_llama3_30_1_0.0_0.0
# Skipping test 1189_llama3_30_1_0.0_0.0
# Skipping test 1190_llama3_30_1_0.0_0.0
# Skipping test 1191_llama3_30_1_0.0_0.0
# Skipping test 1192_llama3_30_1_0.0_0.0
# Skipping test 1193_llama3_30_1_0.0_0.0
# Skipping test 1194_llama3_30_1_0.0_0.0
# Skipping test 1195_llama3_30_1_0.0_0.0
# Skipping test 1196_llama3_30_1_0.0_0.0
# Skipping test 1197_llama3_30_1_0.0_0.0
# Skipping test 1198_llama3_30_1_0.0_0.0
# Skipping test 1199_llama3_30_1_0.0_0.0
# Skipping test 1200_llama3_30_1_0.0_0.0
# Skipping test 1201_llama3_30_1_0.0_0.0
# Skipping test 1202_llama3_30_1_0.0_0.0
# Skipping test 1203_llama3_30_1_0.0_0.0
# Skipping test 1204_llama3_30_1_0.0_0.0
# Skipping test 1205_llama3_30_1_0.0_0.0
# Skipping test 1206_llama3_30_1_0.0_0.0
# Skipping test 1207_llama3_30_1_0.0_0.0
# Skipping test 1208_llama3_30_1_0.0_0.0
# Skipping test 1209_llama3_30_1_0.0_0.0
# Skipping test 1210_llama3_30_1_0.0_0.0
# Skipping test 1211_llama3_30_1_0.0_0.0
# Skipping test 1212_llama3_30_1_0.0_0.0
# Skipping test 1213_llama3_30_1_0.0_0.0
# Skipping test 1214_llama3_30_1_0.0_0.0
# Skipping test 1215_llama3_30_1_0.0_0.0
# Skipping test 1216_llama3_30_1_0.0_0.0
# Skipping test 1217_llama3_30_1_0.0_0.0
# Skipping test 1218_llama3_30_1_0.0_0.0
# Skipping test 1219_llama3_30_1_0.0_0.0
# Skipping test 1220_llama3_30_1_0.0_0.0
# Skipping test 1221_llama3_30_1_0.0_0.0
# Skipping test 1222_llama3_30_1_0.0_0.0
# Skipping test 1223_llama3_30_1_0.0_0.0
# Skipping test 1224_llama3_30_1_0.0_0.0
# Skipping test 1225_llama3_30_1_0.0_0.0
# Skipping test 1226_llama3_30_1_0.0_0.0
# Skipping test 1227_llama3_30_1_0.0_0.0
# Skipping test 1228_llama3_30_1_0.0_0.0
# Skipping test 1229_llama3_30_1_0.0_0.0
# Skipping test 1230_llama3_30_1_0.0_0.0
# Skipping test 1231_llama3_30_1_0.0_0.0
# Skipping test 1232_llama3_30_1_0.0_0.0
# Skipping test 1233_llama3_30_1_0.0_0.0
# Skipping test 1234_llama3_30_1_0.0_0.0
# Skipping test 1235_llama3_30_1_0.0_0.0
# Skipping test 1236_llama3_30_1_0.0_0.0
# Skipping test 1237_llama3_30_1_0.0_0.0
# Skipping test 1238_llama3_30_1_0.0_0.0
# Skipping test 1239_llama3_30_1_0.0_0.0
# Skipping test 1240_llama3_30_1_0.0_0.0
# Skipping test 1241_llama3_30_1_0.0_0.0
# Skipping test 1242_llama3_30_1_0.0_0.0
# Skipping test 1243_llama3_30_1_0.0_0.0
# Skipping test 1244_llama3_30_1_0.0_0.0
# Skipping test 1245_llama3_30_1_0.0_0.0
# Skipping test 1246_llama3_30_1_0.0_0.0
# Skipping test 1247_llama3_30_1_0.0_0.0
# Skipping test 1248_llama3_30_1_0.0_0.0
# Skipping test 1249_llama3_30_1_0.0_0.0
# Skipping test 1250_llama3_30_1_0.0_0.0
# Skipping test 1251_llama3_30_1_0.0_0.0
# Skipping test 1252_llama3_30_1_0.0_0.0
# Skipping test 1253_llama3_30_1_0.0_0.0
# Skipping test 1254_llama3_30_1_0.0_0.0
# Skipping test 1255_llama3_30_1_0.0_0.0
# Skipping test 1256_llama3_30_1_0.0_0.0
# ...
# Skipping test 2090_mixtral_30_1_0.0_0.0
# Skipping test 2091_mixtral_30_1_0.0_0.0
# Skipping test 2092_mixtral_30_1_0.0_0.0
# Skipping test 2093_mixtral_30_1_0.0_0.0
# Skipping test 2094_mixtral_30_1_0.0_0.0
# Skipping test 2095_mixtral_30_1_0.0_0.0
# Skipping test 2096_mixtral_30_1_0.0_0.0
# Skipping test 2097_mixtral_30_1_0.0_0.0
# Skipping test 2098_mixtral_30_1_0.0_0.0
# Skipping test 2099_mixtral_30_1_0.0_0.0
# Skipping test 2100_mixtral_30_1_0.0_0.0
# Skipping test 2101_mixtral_30_1_0.0_0.0
# Skipping test 2102_mixtral_30_1_0.0_0.0
# Skipping test 2103_mixtral_30_1_0.0_0.0
# Skipping test 2104_mixtral_30_1_0.0_0.0
# Skipping test 2105_mixtral_30_1_0.0_0.0
# Skipping test 2106_mixtral_30_1_0.0_0.0
# Skipping test 2107_mixtral_30_1_0.0_0.0
# Skipping test 2108_mixtral_30_1_0.0_0.0
# Skipping test 2109_mixtral_30_1_0.0_0.0
# Skipping test 2110_mixtral_30_1_0.0_0.0
# Skipping test 2111_mixtral_30_1_0.0_0.0
# Skipping test 2112_mixtral_30_1_0.0_0.0
# Skipping test 2113_mixtral_30_1_0.0_0.0
# Skipping test 2114_mixtral_30_1_0.0_0.0
# Skipping test 2115_mixtral_30_1_0.0_0.0
# Skipping test 2116_mixtral_30_1_0.0_0.0
# Skipping test 2117_mixtral_30_1_0.0_0.0
# Skipping test 2118_mixtral_30_1_0.0_0.0
# Skipping test 2119_mixtral_30_1_0.0_0.0
# Skipping test 2120_mixtral_30_1_0.0_0.0
# Skipping test 2121_mixtral_30_1_0.0_0.0
# Skipping test 2122_mixtral_30_1_0.0_0.0
# Skipping test 2123_mixtral_30_1_0.0_0.0
# Skipping test 2124_mixtral_30_1_0.0_0.0
# Skipping test 2125_mixtral_30_1_0.0_0.0
# Skipping test 2126_mixtral_30_1_0.0_0.0
# Skipping test 2127_mixtral_30_1_0.0_0.0
# Skipping test 2128_mixtral_30_1_0.0_0.0
# Skipping test 2129_mixtral_30_1_0.0_0.0
# Skipping test 2130_mixtral_30_1_0.0_0.0
# Skipping test 2131_mixtral_30_1_0.0_0.0
# Skipping test 2132_mixtral_30_1_0.0_0.0
# Skipping test 2133_mixtral_30_1_0.0_0.0
# Skipping test 2134_mixtral_30_1_0.0_0.0
# Skipping test 2135_mixtral_30_1_0.0_0.0
# Skipping test 2136_mixtral_30_1_0.0_0.0
# Skipping test 2137_mixtral_30_1_0.0_0.0
# Skipping test 2138_mixtral_30_1_0.0_0.0
# Skipping test 2139_mixtral_30_1_0.0_0.0
# Skipping test 2140_mixtral_30_1_0.0_0.0
# Skipping test 2141_mixtral_30_1_0.0_0.0
# Skipping test 2142_mixtral_30_1_0.0_0.0
# Skipping test 2143_mixtral_30_1_0.0_0.0
# Skipping test 2144_mixtral_30_1_0.0_0.0
# Skipping test 2145_mixtral_30_1_0.0_0.0
# Skipping test 2146_mixtral_30_1_0.0_0.0
# Skipping test 2147_mixtral_30_1_0.0_0.0
# Skipping test 2148_mixtral_30_1_0.0_0.0
# Skipping test 2149_mixtral_30_1_0.0_0.0
# Skipping test 2150_mixtral_30_1_0.0_0.0
# Skipping test 2151_mixtral_30_1_0.0_0.0
# Skipping test 2152_mixtral_30_1_0.0_0.0
# Skipping test 2153_mixtral_30_1_0.0_0.0
# Skipping test 2154_mixtral_30_1_0.0_0.0
# Skipping test 2155_mixtral_30_1_0.0_0.0
# Skipping test 2156_mixtral_30_1_0.0_0.0
# Skipping test 2157_mixtral_30_1_0.0_0.0
# Skipping test 2158_mixtral_30_1_0.0_0.0
# Skipping test 2159_mixtral_30_1_0.0_0.0
# Skipping test 2160_mixtral_30_1_0.0_0.0
# Skipping test 2161_mixtral_30_1_0.0_0.0
# Skipping test 2162_mixtral_30_1_0.0_0.0
# Skipping test 2163_mixtral_30_1_0.0_0.0
# Skipping test 2164_mixtral_30_1_0.0_0.0
# Skipping test 2165_mixtral_30_1_0.0_0.0
# Skipping test 2166_mixtral_30_1_0.0_0.0
# Skipping test 2167_mixtral_30_1_0.0_0.0
# Skipping test 2168_mixtral_30_1_0.0_0.0
# Skipping test 2169_mixtral_30_1_0.0_0.0
# Skipping test 2170_mixtral_30_1_0.0_0.0
# Skipping test 2171_mixtral_30_1_0.0_0.0
# Skipping test 2172_mixtral_30_1_0.0_0.0
# Skipping test 2173_mixtral_30_1_0.0_0.0
# Skipping test 2174_mixtral_30_1_0.0_0.0
# Skipping test 2175_mixtral_30_1_0.0_0.0
# Skipping test 2176_mixtral_30_1_0.0_0.0
# Skipping test 2177_mixtral_30_1_0.0_0.0
# Skipping test 2178_mixtral_30_1_0.0_0.0
# Skipping test 2179_mixtral_30_1_0.0_0.0
# Skipping test 2180_mixtral_30_1_0.0_0.0
# Skipping test 2181_mixtral_30_1_0.0_0.0
# Skipping test 2182_mixtral_30_1_0.0_0.0
# Skipping test 2183_mixtral_30_1_0.0_0.0
# Skipping test 2184_mixtral_30_1_0.0_0.0
# Skipping test 2185_mixtral_30_1_0.0_0.0
# Skipping test 2186_mixtral_30_1_0.0_0.0
# Skipping test 2187_mixtral_30_1_0.0_0.0
# Skipping test 2188_mixtral_30_1_0.0_0.0
# Skipping test 2189_mixtral_30_1_0.0_0.0
# Skipping test 2190_mixtral_30_1_0.0_0.0
# Skipping test 2191_mixtral_30_1_0.0_0.0
# Skipping test 2192_mixtral_30_1_0.0_0.0
# Skipping test 2193_mixtral_30_1_0.0_0.0
# Skipping test 2194_mixtral_30_1_0.0_0.0
# Skipping test 2195_mixtral_30_1_0.0_0.0
# Skipping test 2196_mixtral_30_1_0.0_0.0
# Skipping test 2197_mixtral_30_1_0.0_0.0
# Skipping test 2198_mixtral_30_1_0.0_0.0
# Skipping test 2199_mixtral_30_1_0.0_0.0
# Skipping test 2200_mixtral_30_1_0.0_0.0
# Skipping test 2201_mixtral_30_1_0.0_0.0
# Skipping test 2202_mixtral_30_1_0.0_0.0
# Skipping test 2203_mixtral_30_1_0.0_0.0
# Skipping test 2204_mixtral_30_1_0.0_0.0
# Skipping test 2205_mixtral_30_1_0.0_0.0
# Skipping test 2206_mixtral_30_1_0.0_0.0
# Skipping test 2207_mixtral_30_1_0.0_0.0
# Skipping test 2208_mixtral_30_1_0.0_0.0
# Skipping test 2209_mixtral_30_1_0.0_0.0
# Skipping test 2210_mixtral_30_1_0.0_0.0
# Skipping test 2211_mixtral_30_1_0.0_0.0
# Skipping test 2212_mixtral_30_1_0.0_0.0
# Skipping test 2213_mixtral_30_1_0.0_0.0
# Skipping test 2214_mixtral_30_1_0.0_0.0
# Skipping test 2215_mixtral_30_1_0.0_0.0
# Skipping test 2216_mixtral_30_1_0.0_0.0
# Skipping test 2217_mixtral_30_1_0.0_0.0
# Skipping test 2218_mixtral_30_1_0.0_0.0
# Skipping test 2219_mixtral_30_1_0.0_0.0
# Skipping test 2220_mixtral_30_1_0.0_0.0
# Skipping test 2221_mixtral_30_1_0.0_0.0
# Skipping test 2222_mixtral_30_1_0.0_0.0
# Skipping test 2223_mixtral_30_1_0.0_0.0
# Skipping test 2224_mixtral_30_1_0.0_0.0
# Skipping test 2225_mixtral_30_1_0.0_0.0
# Skipping test 2226_mixtral_30_1_0.0_0.0
# Skipping test 2227_mixtral_30_1_0.0_0.0
# Skipping test 2228_mixtral_30_1_0.0_0.0
# Skipping test 2229_mixtral_30_1_0.0_0.0
# Skipping test 2230_mixtral_30_1_0.0_0.0
# Skipping test 2231_mixtral_30_1_0.0_0.0
# Skipping test 2232_mixtral_30_1_0.0_0.0
# Skipping test 2233_mixtral_30_1_0.0_0.0
# Skipping test 2234_mixtral_30_1_0.0_0.0
# Skipping test 2235_mixtral_30_1_0.0_0.0
# Skipping test 2236_mixtral_30_1_0.0_0.0
# Skipping test 2237_mixtral_30_1_0.0_0.0
# Skipping test 2238_mixtral_30_1_0.0_0.0
# Skipping test 2239_mixtral_30_1_0.0_0.0
# Skipping test 2240_mixtral_30_1_0.0_0.0
# Skipping test 2241_mixtral_30_1_0.0_0.0
# Skipping test 2242_mixtral_30_1_0.0_0.0
# Skipping test 2243_mixtral_30_1_0.0_0.0
# Skipping test 2244_mixtral_30_1_0.0_0.0
# Skipping test 2245_mixtral_30_1_0.0_0.0
# Skipping test 2246_mixtral_30_1_0.0_0.0
# Skipping test 2247_mixtral_30_1_0.0_0.0
# Skipping test 2248_mixtral_30_1_0.0_0.0
# Skipping test 2249_mixtral_30_1_0.0_0.0
# Skipping test 2250_mixtral_30_1_0.0_0.0
# Skipping test 2251_mixtral_30_1_0.0_0.0
# Skipping test 2252_mixtral_30_1_0.0_0.0
# Skipping test 2253_mixtral_30_1_0.0_0.0
# Skipping test 2254_mixtral_30_1_0.0_0.0
# Skipping test 2255_mixtral_30_1_0.0_0.0
# Skipping test 2256_mixtral_30_1_0.0_0.0
# Skipping test 2257_mixtral_30_1_0.0_0.0
# Skipping test 2258_mixtral_30_1_0.0_0.0
# Skipping test 2259_mixtral_30_1_0.0_0.0
# Skipping test 2260_mixtral_30_1_0.0_0.0
# Skipping test 2261_mixtral_30_1_0.0_0.0
# Skipping test 2262_mixtral_30_1_0.0_0.0
# Skipping test 2263_mixtral_30_1_0.0_0.0
# Skipping test 2264_mixtral_30_1_0.0_0.0
# Skipping test 2265_mixtral_30_1_0.0_0.0
# Skipping test 2266_mixtral_30_1_0.0_0.0
# Skipping test 2267_mixtral_30_1_0.0_0.0
# Skipping test 2268_mixtral_30_1_0.0_0.0
# Skipping test 2269_mixtral_30_1_0.0_0.0
# Skipping test 2270_mixtral_30_1_0.0_0.0
# Skipping test 2271_mixtral_30_1_0.0_0.0
# Skipping test 2272_mixtral_30_1_0.0_0.0
# Skipping test 2273_mixtral_30_1_0.0_0.0
# Skipping test 2274_mixtral_30_1_0.0_0.0
# Skipping test 2275_mixtral_30_1_0.0_0.0
# Skipping test 2276_mixtral_30_1_0.0_0.0
# Skipping test 2277_mixtral_30_1_0.0_0.0
# Skipping test 2278_mixtral_30_1_0.0_0.0
# Skipping test 2279_mixtral_30_1_0.0_0.0
# Skipping test 2280_mixtral_30_1_0.0_0.0
# Skipping test 2281_mixtral_30_1_0.0_0.0
# Skipping test 2282_mixtral_30_1_0.0_0.0
# Skipping test 2283_mixtral_30_1_0.0_0.0
# Skipping test 2284_mixtral_30_1_0.0_0.0
# Skipping test 2285_mixtral_30_1_0.0_0.0
# Skipping test 2286_mixtral_30_1_0.0_0.0
# Skipping test 2287_mixtral_30_1_0.0_0.0
# Skipping test 2288_mixtral_30_1_0.0_0.0
# Skipping test 2289_mixtral_30_1_0.0_0.0
# Skipping test 2290_mixtral_30_1_0.0_0.0
# Skipping test 2291_mixtral_30_1_0.0_0.0
# Skipping test 2292_mixtral_30_1_0.0_0.0
# Skipping test 2293_mixtral_30_1_0.0_0.0
# Skipping test 2294_mixtral_30_1_0.0_0.0
# Skipping test 2295_mixtral_30_1_0.0_0.0
# Skipping test 2296_mixtral_30_1_0.0_0.0
# Skipping test 2297_mixtral_30_1_0.0_0.0
# Skipping test 2298_mixtral_30_1_0.0_0.0
# Skipping test 2299_mixtral_30_1_0.0_0.0
# Skipping test 2300_mixtral_30_1_0.0_0.0
# Skipping test 2301_mixtral_30_1_0.0_0.0
# Skipping test 2302_mixtral_30_1_0.0_0.0
# Skipping test 2303_mixtral_30_1_0.0_0.0
# Skipping test 2304_mixtral_30_1_0.0_0.0
# Skipping test 2305_mixtral_30_1_0.0_0.0
# Skipping test 2306_mixtral_30_1_0.0_0.0
# Skipping test 2307_mixtral_30_1_0.0_0.0
# Skipping test 2308_mixtral_30_1_0.0_0.0
# Skipping test 2309_mixtral_30_1_0.0_0.0
# Skipping test 2310_mixtral_30_1_0.0_0.0
# Skipping test 2311_mixtral_30_1_0.0_0.0
# Skipping test 2312_mixtral_30_1_0.0_0.0
# Skipping test 2313_mixtral_30_1_0.0_0.0
# Skipping test 2314_mixtral_30_1_0.0_0.0
# Skipping test 2315_mixtral_30_1_0.0_0.0
# Skipping test 2316_mixtral_30_1_0.0_0.0
# Skipping test 2317_mixtral_30_1_0.0_0.0
# Skipping test 2318_mixtral_30_1_0.0_0.0
# Skipping test 2319_mixtral_30_1_0.0_0.0
# Skipping test 2320_mixtral_30_1_0.0_0.0
# Skipping test 2321_mixtral_30_1_0.0_0.0
# Skipping test 2322_mixtral_30_1_0.0_0.0
# Skipping test 2323_mixtral_30_1_0.0_0.0
# Skipping test 2324_mixtral_30_1_0.0_0.0
# Skipping test 2325_mixtral_30_1_0.0_0.0
# Skipping test 2326_mixtral_30_1_0.0_0.0
# Skipping test 2327_mixtral_30_1_0.0_0.0
# Skipping test 2328_mixtral_30_1_0.0_0.0
# Skipping test 2329_mixtral_30_1_0.0_0.0
# Skipping test 2330_mixtral_30_1_0.0_0.0
# Skipping test 2331_mixtral_30_1_0.0_0.0
# Skipping test 2332_mixtral_30_1_0.0_0.0
# Skipping test 2333_mixtral_30_1_0.0_0.0
# Skipping test 2334_mixtral_30_1_0.0_0.0
# Skipping test 2335_mixtral_30_1_0.0_0.0
# Skipping test 2336_mixtral_30_1_0.0_0.0
# Skipping test 2337_mixtral_30_1_0.0_0.0
# Skipping test 2338_mixtral_30_1_0.0_0.0
# Skipping test 2339_mixtral_30_1_0.0_0.0
# Skipping test 2340_mixtral_30_1_0.0_0.0
# Skipping test 2341_mixtral_30_1_0.0_0.0
# Skipping test 2342_mixtral_30_1_0.0_0.0
# Skipping test 2343_mixtral_30_1_0.0_0.0
# Skipping test 2344_mixtral_30_1_0.0_0.0
# Skipping test 2345_mixtral_30_1_0.0_0.0
# Skipping test 2346_mixtral_30_1_0.0_0.0
# Skipping test 2347_mixtral_30_1_0.0_0.0
# Skipping test 2348_mixtral_30_1_0.0_0.0
# Skipping test 2349_mixtral_30_1_0.0_0.0
# Skipping test 2350_mixtral_30_1_0.0_0.0
# Skipping test 2351_mixtral_30_1_0.0_0.0
# Skipping test 2352_mixtral_30_1_0.0_0.0
# Skipping test 2353_mixtral_30_1_0.0_0.0
# Skipping test 2354_mixtral_30_1_0.0_0.0
# Skipping test 2355_mixtral_30_1_0.0_0.0
# Skipping test 2356_mixtral_30_1_0.0_0.0
# Skipping test 2357_mixtral_30_1_0.0_0.0
# Skipping test 2358_mixtral_30_1_0.0_0.0
# Skipping test 2359_mixtral_30_1_0.0_0.0
# Skipping test 2360_mixtral_30_1_0.0_0.0
# Skipping test 2361_mixtral_30_1_0.0_0.0
# Skipping test 2362_mixtral_30_1_0.0_0.0
# Skipping test 2363_mixtral_30_1_0.0_0.0
# Skipping test 2364_mixtral_30_1_0.0_0.0
# Skipping test 2365_mixtral_30_1_0.0_0.0
# Skipping test 2366_mixtral_30_1_0.0_0.0
# Skipping test 2367_mixtral_30_1_0.0_0.0
# Skipping test 2368_mixtral_30_1_0.0_0.0
# Skipping test 2369_mixtral_30_1_0.0_0.0
# Skipping test 2370_mixtral_30_1_0.0_0.0
# Skipping test 2371_mixtral_30_1_0.0_0.0
# Skipping test 2372_mixtral_30_1_0.0_0.0
# Skipping test 2373_mixtral_30_1_0.0_0.0
# Skipping test 2374_mixtral_30_1_0.0_0.0
# Skipping test 2375_mixtral_30_1_0.0_0.0
# Skipping test 2376_mixtral_30_1_0.0_0.0
# Skipping test 2377_mixtral_30_1_0.0_0.0
# Skipping test 2378_mixtral_30_1_0.0_0.0
# Skipping test 2379_mixtral_30_1_0.0_0.0
# Skipping test 2380_mixtral_30_1_0.0_0.0
# Skipping test 2381_mixtral_30_1_0.0_0.0
# Skipping test 2382_mixtral_30_1_0.0_0.0
# Skipping test 2383_mixtral_30_1_0.0_0.0
# Skipping test 2384_mixtral_30_1_0.0_0.0
# Skipping test 2385_mixtral_30_1_0.0_0.0
# Skipping test 2386_mixtral_30_1_0.0_0.0
# Skipping test 2387_mixtral_30_1_0.0_0.0
# Skipping test 2388_mixtral_30_1_0.0_0.0
# Skipping test 2389_mixtral_30_1_0.0_0.0
# Skipping test 2390_mixtral_30_1_0.0_0.0
# Skipping test 2391_mixtral_30_1_0.0_0.0
# Skipping test 2392_mixtral_30_1_0.0_0.0
# Skipping test 2393_mixtral_30_1_0.0_0.0
# Skipping test 2394_mixtral_30_1_0.0_0.0
# Skipping test 2395_mixtral_30_1_0.0_0.0
# Skipping test 2396_mixtral_30_1_0.0_0.0
# Skipping test 2397_mixtral_30_1_0.0_0.0
# Skipping test 2398_mixtral_30_1_0.0_0.0
# Skipping test 2399_mixtral_30_1_0.0_0.0
# Skipping test 2400_mixtral_30_1_0.0_0.0
# Skipping test 2401_mixtral_30_1_0.0_0.0
# Skipping test 2402_mixtral_30_1_0.0_0.0
# Skipping test 2403_mixtral_30_1_0.0_0.0
# Skipping test 2404_mixtral_30_1_0.0_0.0
# Skipping test 2405_mixtral_30_1_0.0_0.0
# Skipping test 2406_mixtral_30_1_0.0_0.0
# Skipping test 2407_mixtral_30_1_0.0_0.0
# Skipping test 2408_mixtral_30_1_0.0_0.0
# Skipping test 2409_mixtral_30_1_0.0_0.0
# Skipping test 2410_mixtral_30_1_0.0_0.0
# Skipping test 2411_mixtral_30_1_0.0_0.0
# Skipping test 2412_mixtral_30_1_0.0_0.0
# Skipping test 2413_mixtral_30_1_0.0_0.0
# Skipping test 2414_mixtral_30_1_0.0_0.0
# Skipping test 2415_mixtral_30_1_0.0_0.0
# Skipping test 2416_mixtral_30_1_0.0_0.0
# Skipping test 2417_mixtral_30_1_0.0_0.0
# Skipping test 2418_mixtral_30_1_0.0_0.0
# Skipping test 2419_mixtral_30_1_0.0_0.0
# Skipping test 2420_mixtral_30_1_0.0_0.0
# Skipping test 2421_mixtral_30_1_0.0_0.0
# Skipping test 2422_mixtral_30_1_0.0_0.0
# Skipping test 2423_mixtral_30_1_0.0_0.0
# Skipping test 2424_mixtral_30_1_0.0_0.0
# Skipping test 2425_mixtral_30_1_0.0_0.0
# Skipping test 2426_mixtral_30_1_0.0_0.0
# Skipping test 2427_mixtral_30_1_0.0_0.0
# Skipping test 2428_mixtral_30_1_0.0_0.0
# Skipping test 2429_mixtral_30_1_0.0_0.0
# Skipping test 2430_mixtral_30_1_0.0_0.0
# Skipping test 2431_mixtral_30_1_0.0_0.0
# Skipping test 2432_mixtral_30_1_0.0_0.0
# Skipping test 2433_mixtral_30_1_0.0_0.0
# Skipping test 2434_mixtral_30_1_0.0_0.0
# Skipping test 2435_mixtral_30_1_0.0_0.0
# Skipping test 2436_mixtral_30_1_0.0_0.0
# Skipping test 2437_mixtral_30_1_0.0_0.0
# Skipping test 2438_mixtral_30_1_0.0_0.0
# Skipping test 2439_mixtral_30_1_0.0_0.0
# Skipping test 2440_mixtral_30_1_0.0_0.0
# Skipping test 2441_mixtral_30_1_0.0_0.0
# Skipping test 2442_mixtral_30_1_0.0_0.0
# Skipping test 2443_mixtral_30_1_0.0_0.0
# Skipping test 2444_mixtral_30_1_0.0_0.0
# Skipping test 2445_mixtral_30_1_0.0_0.0
# Skipping test 2446_mixtral_30_1_0.0_0.0
# Skipping test 2447_mixtral_30_1_0.0_0.0
# Skipping test 2448_mixtral_30_1_0.0_0.0
# Skipping test 2449_mixtral_30_1_0.0_0.0
# Skipping test 2450_mixtral_30_1_0.0_0.0
# Skipping test 2451_mixtral_30_1_0.0_0.0
# Skipping test 2452_mixtral_30_1_0.0_0.0
# Skipping test 2453_mixtral_30_1_0.0_0.0
# Skipping test 2454_mixtral_30_1_0.0_0.0
# Skipping test 2455_mixtral_30_1_0.0_0.0
# Skipping test 2456_mixtral_30_1_0.0_0.0
# Skipping test 2457_mixtral_30_1_0.0_0.0
# Skipping test 2458_mixtral_30_1_0.0_0.0
# Skipping test 2459_mixtral_30_1_0.0_0.0
# Skipping test 2460_mixtral_30_1_0.0_0.0
# Skipping test 2461_mixtral_30_1_0.0_0.0
# Skipping test 2462_mixtral_30_1_0.0_0.0
# Skipping test 2463_mixtral_30_1_0.0_0.0
# Skipping test 2464_mixtral_30_1_0.0_0.0
# Skipping test 2465_mixtral_30_1_0.0_0.0
# Skipping test 2466_mixtral_30_1_0.0_0.0
# Skipping test 2467_mixtral_30_1_0.0_0.0
# Skipping test 2468_mixtral_30_1_0.0_0.0
# Skipping test 2469_mixtral_30_1_0.0_0.0
# Skipping test 2470_mixtral_30_1_0.0_0.0
# Skipping test 2471_mixtral_30_1_0.0_0.0
# Skipping test 2472_mixtral_30_1_0.0_0.0
# Skipping test 2473_mixtral_30_1_0.0_0.0
# Skipping test 2474_mixtral_30_1_0.0_0.0
# Skipping test 2475_mixtral_30_1_0.0_0.0
# Skipping test 2476_mixtral_30_1_0.0_0.0
# Skipping test 2477_mixtral_30_1_0.0_0.0
# Skipping test 2478_mixtral_30_1_0.0_0.0
# Skipping test 2479_mixtral_30_1_0.0_0.0
# Skipping test 2480_mixtral_30_1_0.0_0.0
# Skipping test 2481_mixtral_30_1_0.0_0.0
# Skipping test 2482_mixtral_30_1_0.0_0.0
# Skipping test 2483_mixtral_30_1_0.0_0.0
# Skipping test 2484_mixtral_30_1_0.0_0.0
# Skipping test 2485_mixtral_30_1_0.0_0.0
# Skipping test 2486_mixtral_30_1_0.0_0.0
# Skipping test 2487_mixtral_30_1_0.0_0.0
# Skipping test 2488_mixtral_30_1_0.0_0.0
# Skipping test 2489_mixtral_30_1_0.0_0.0

# %%
plot_TVD_info(sample_ids,
              prompt_types,
              llms,
              Qs,
              temp_questions,
              As,
              temp_answers,
              class_labels,
              results_folder)

# %%
plot_questions_vs_predicted_distribution(sample_ids,
                                        prompt_types,
                                        llms,
                                        Qs,
                                        temp_questions,
                                        As,
                                        temp_answers,
                                        class_labels,
                                        results_folder)

# %%
plot_questions_vs_class_sensitivity(sample_ids,
                               prompt_types,
                               llms,
                               Qs,
                               temp_questions,
                               As,
                               temp_answers,
                               class_labels,
                               results_folder)

# %%
for llm in ['llama3', 'mixtral']:
    for prompt_type in ['simple', 'instruct', 'fewshot']:
        print(llm, prompt_type)
        Q = 30
        A = 1  # MUST stay 1
        temp_question = 0.
        temp_answer = 0.
        max_value = 1
        
        print_classification_scores(sample_ids,
                                    prompt_type,
                                    llm,
                                    Q,
                                    temp_question,
                                    A,
                                    temp_answer,
                                    class_labels,
                                    results_folder)
# Out:
# llama3 simple
# Global scores, accuracy: 0.5694779116465863, micro f1-score: 0.5694779116465863, macro f1-score: 0.3715000673786863
# Standard deviation of microf1 score: 0.06658784311281145
# llama3 instruct
# Global scores, accuracy: 0.5092369477911647, micro f1-score: 0.5092369477911647, macro f1-score: 0.3023460244917477
# Standard deviation of microf1 score: 0.12150988217505188
# llama3 fewshot
# Global scores, accuracy: 0.8176706827309237, micro f1-score: 0.8176706827309237, macro f1-score: 0.5417787942826061
# Standard deviation of microf1 score: 0.013267911789969028
# mixtral simple
# Global scores, accuracy: 0.8140562248995984, micro f1-score: 0.8140562248995984, macro f1-score: 0.5572679254723364
# Standard deviation of microf1 score: 0.03782683431876975
# mixtral instruct
# Global scores, accuracy: 0.7558232931726908, micro f1-score: 0.7558232931726907, macro f1-score: 0.52752302738218
# Standard deviation of microf1 score: 0.041593124994255666
# mixtral fewshot
# Global scores, accuracy: 0.8465863453815261, micro f1-score: 0.8465863453815261, macro f1-score: 0.563213782928413
# Standard deviation of microf1 score: 0.010067690948244994
# gpt-3.5 simple
# Global scores, accuracy: 0.7899598393574297, micro f1-score: 0.7899598393574297, macro f1-score: 0.5307116104868914
# Standard deviation of microf1 score: 0.023057852090882274
# gpt-3.5 instruct
# Global scores, accuracy: 0.7807228915662651, micro f1-score: 0.7807228915662651, macro f1-score: 0.5219744940584414
# Standard deviation of microf1 score: 0.0258298677995084
# gpt-3.5 fewshot
# Global scores, accuracy: 0.7429718875502008, micro f1-score: 0.7429718875502008, macro f1-score: 0.7315320463403722
# Standard deviation of microf1 score: 0.01593325095491065
# gpt-4o simple
# Global scores, accuracy: 0.8779116465863454, micro f1-score: 0.8779116465863454, macro f1-score: 0.5951885471676502
# Standard deviation of microf1 score: 0.05345223952181527
# gpt-4o instruct
# Global scores, accuracy: 0.8887550200803213, micro f1-score: 0.8887550200803213, macro f1-score: 0.5927661733650832
# Standard deviation of microf1 score: 0.006108012868357149
# gpt-4o fewshot
# Global scores, accuracy: 0.9160642570281124, micro f1-score: 0.9160642570281124, macro f1-score: 0.61093271609573
# Standard deviation of microf1 score: 0.006210762545292631

# %%
plot_avg_sensitivity(sample_ids,
                 prompt_types,
                 ['llama3'],
                 Qs,
                 [0.],
                 As,
                 temp_answers,
                 class_labels,
                 results_folder)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_avg_sensitivity(sample_ids,
#       2                  prompt_types,
#       3                  ['llama3'],
#       4                  Qs,
#       5                  [0.],
#       6                  As,
#       7                  temp_answers,
#       8                  class_labels,
#       9                  results_folder)
#
# File ~/PycharmProjects/uncertainty-in-llms/util.py:821, in plot_avg_sensitivity(sample_ids, prompt_types, llms, Qs, temp_questions, As, temp_answers, class_labels, results_folder)
#     818 # Open the JSON file and load its contents into a Python dictionary
#     819 with open(Path(results_folder, filename),
#     820           'r') as f:
# --> 821     data_dict = json.load(f)
#     823 entropy_matrix = np.zeros((Q, n_classes))
#     825 for q in range(Q):
#
# File /usr/lib/python3.10/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/lib/python3.10/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %%
for llm in ['llama3', 'mixtral']:
    Q = 30
    A = 1  # MUST stay 1
    temp_question = 0.
    temp_answer = 0.
    
    data = []
    
    for prompt_type in ['simple', 'instruct', 'fewshot']:
        print(llm, prompt_type)
        em = print_test_sensitivity_over_samples(sample_ids,
                                        prompt_type,
                                        llm,
                                        Q,
                                        temp_question,
                                        A,
                                        temp_answer,
                                        class_labels,
                                        results_folder)
    
        data.append((em, prompt_type))
    
    # Prepare lists to collect expanded data
    expanded_values = []
    expanded_labels = []
    
    # Expand the data into individual points
    for arr, label in data:
        expanded_values.extend(arr)
        expanded_labels.extend([label] * len(arr))
    
    # Create a DataFrame from the expanded data
    df = pd.DataFrame({'Values': expanded_values, 'Label': expanded_labels})
    
    # Plot the violin plot
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    ax =sns.violinplot(x='Label', y='Values', data=df, split=False)
    plt.xlabel(None)
    ax.set_xticks(np.arange(3)) # <--- set the ticks first
    ax.set_xticklabels(['Simple', 'Detail', '1-shot'])
    plt.ylabel('Entropy')
    plt.show()
# Out:
# llama3 simple
# Avg Entropy over samples: 0.15689349844926076,Std (over questions): 0.24442056131231674
# llama3 instruct
# Avg Entropy over samples: 0.21323642968569204,Std (over questions): 0.28925746726542995
# llama3 fewshot
# Avg Entropy over samples: 0.04825207230922011,Std (over questions): 0.16041886179920312
# mixtral simple
# Avg Entropy over samples: 0.19475169146882296,Std (over questions): 0.2779043304966564
# mixtral instruct
# Avg Entropy over samples: 0.1755831897599826,Std (over questions): 0.26380520963434484
# mixtral fewshot
# Avg Entropy over samples: 0.0461713000077939,Std (over questions): 0.15286904169249171
# gpt-3.5 simple
# Avg Entropy over samples: 0.2925858621634325,Std (over questions): 0.22981899672969194
# gpt-3.5 instruct
# Avg Entropy over samples: 0.3466592964126296,Std (over questions): 0.23224543775582485
# gpt-3.5 fewshot
# Avg Entropy over samples: 0.21875203405341345,Std (over questions): 0.2343692931489408
# gpt-4o simple
# Avg Entropy over samples: 0.23319786646327256,Std (over questions): 0.2950941685406532
# gpt-4o instruct
# Avg Entropy over samples: 0.0871524025896046,Std (over questions): 0.1877328501952838
# gpt-4o fewshot
# Avg Entropy over samples: 0.07397598248716213,Std (over questions): 0.16898495148622897

# %%
if not os.path.exists(Path(results_folder, 'paper_figures')):
    os.makedirs(Path(results_folder, 'paper_figures'))
    
# Configure matplotlib to use LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
# Set the global font size
plt.rc('font', size=20)  # Example: set the font size to 14

sns.set_style("whitegrid")
sns.color_palette("colorblind")

dataset="RTE"

figsize=(7.5,4.5)
n_samples, n_classes = len(samples), len(class_labels)

for llm in ['llama3', 'mixtral']:
    Q = 30
    A = 1  # MUST stay 1
    temp_question = 0.
    temp_answer = 0.
    
    data = []

    for prompt_type in ['simple', 'instruct', 'fewshot']:
        print(llm, prompt_type)
        TVD_matrix_per_class = print_consistency(sample_ids,
                                       prompt_type,
                                       llm,
                                       Q,
                                       temp_question,
                                       A,
                                       temp_answer,
                                       class_labels,
                                       results_folder)
    
        for c, TVD_matrix in enumerate(TVD_matrix_per_class):
            data.append((TVD_matrix.reshape(-1), prompt_type))
            
            c_name = class_labels[c]

            # plt.figure(figsize=(figsize[0]+1, figsize[0]))
            # ax = sns.heatmap(TVD_matrix, cbar_kws={'orientation': 'horizontal'})
            # plt.xlabel("Sample ID",fontsize=26)
            # plt.ylabel("Sample ID",fontsize=26)
            # Adjust the layout to make room for the colorbar
            # plt.tight_layout()
            # plt.savefig(Path(results_folder, 'paper_figures', f'TVD_matrix_{dataset}_{prompt_type}_{llm}_{Q}_{A}_{temp_question}_{temp_answer}_{c_name}.pdf'))
            #plt.show()

            # sns.histplot(np.reshape(TVD_matrix, -1),
            #                         bins=20, stat='probability', kde=False, color='#3274A1', alpha=1.)
            # plt.xlabel(r"$C_y(x,x')$")
            # plt.tight_layout()
            # plt.savefig(Path(results_folder, 'paper_figures', f'TVD_hist_{dataset}_{prompt_type}_{llm}_{Q}_{A}_{temp_question}_{temp_answer}_{c_name}.pdf'))
            #plt.show()
    
    
    # Prepare lists to collect expanded data
    expanded_values = []
    expanded_labels = []
    
    # Expand the data into individual points
    for arr, label in data:
        expanded_values.extend(arr)
        expanded_labels.extend([label] * len(arr))
    
    # Create a DataFrame from the expanded data
    df = pd.DataFrame({'Values': expanded_values, 'Label': expanded_labels})
    
    # Plot the violin plot
    # plt.figure(figsize=figsize)  # Adjust the figure size if needed
    # ax = sns.violinplot(x='Label', y='Values', data=df, split=False)
    # plt.xlabel(None)
    # ax.set_xticks(np.arange(3)) # <--- set the ticks first
    # ax.set_xticklabels(['Simple', 'Detail', '1-shot'])
    # plt.ylim(0, 1)
    # plt.ylabel('Consistency')
    # plt.tight_layout()
    # plt.savefig(Path(results_folder, 'paper_figures',
    #         f'consistency_vs_prompting_{dataset}_{llm}_{Q}_{A}_{temp_question}_{temp_answer}.pdf'))
    # plt.show()
# Out:
# llama3 simple
# Prompt type: simple
# Avg consistency over classes: 0.7010537785774698,Std consistency over classes: 0.3972415297995795
# llama3 instruct
# Prompt type: instruct
# Avg consistency over classes: 0.7271405294010503,Std consistency over classes: 0.3890688032600171
# llama3 fewshot
# Prompt type: fewshot
# Avg consistency over classes: 0.755346105898704,Std consistency over classes: 0.40234636146448516
# mixtral simple
# Prompt type: simple
# Avg consistency over classes: 0.6693631329751921,Std consistency over classes: 0.376786861736134
# mixtral instruct
# Prompt type: instruct
# Avg consistency over classes: 0.6759650013558781,Std consistency over classes: 0.3839209517457362
# mixtral fewshot
# Prompt type: fewshot
# Avg consistency over classes: 0.7542638549560945,Std consistency over classes: 0.4017007584029423
# gpt-3.5 simple
# Prompt type: simple
# Avg consistency over classes: 0.7198186800650221,Std consistency over classes: 0.26701103237109824
# gpt-3.5 instruct
# Prompt type: instruct
# Avg consistency over classes: 0.719884355747149,Std consistency over classes: 0.24543964769914847
# gpt-3.5 fewshot
# Prompt type: fewshot
# Avg consistency over classes: 0.703293439764927,Std consistency over classes: 0.309831431976043
# gpt-4o simple
# Prompt type: simple
# Avg consistency over classes: 0.7570659528790957,Std consistency over classes: 0.3006460975249509
# gpt-4o instruct
# Prompt type: instruct
# Avg consistency over classes: 0.8236128592727544,Std consistency over classes: 0.30534297062122523
# gpt-4o fewshot
# Prompt type: fewshot
# Avg consistency over classes: 0.8359047061765889,Std consistency over classes: 0.30219615774961167

# %%
# Configure matplotlib to use LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
# Set the global font size
plt.rc('font', size=20)  # Example: set the font size to 14

sns.set_style("whitegrid")
sns.color_palette("colorblind")

figsize=(7.5,4.5)

for llm in ['llama3', 'mixtral']:
    Q = 30
    A = 1  # MUST stay 1
    temp_question = 0.
    temp_answer = 0.
    
    data = []

    errorbar_fig = plt.figure(figsize=figsize)

    
    for prompt_type in ['simple', 'instruct', 'fewshot']:
        print(llm, prompt_type)
        em = print_test_sensitivity_over_samples(sample_ids,
                                        prompt_type,
                                        llm,
                                        Q,
                                        temp_question,
                                        A,
                                        temp_answer,
                                        class_labels,
                                        results_folder)

        sens_per_class = sensitivity_per_class(sample_ids,
                                               prompt_type,
                                               llm,
                                               Q,
                                               temp_question,
                                               A,
                                               temp_answer,
                                               class_labels,
                                               results_folder)

        # Add error bars (standard deviation)
        plt.figure(errorbar_fig)
        if prompt_type == 'instruct':
            label = 'Detail'
        elif prompt_type == 'fewshot':
            label = '1-shot'
        else:
            label = 'Simple'

        sens_per_class_mean = np.array([np.array(sens_per_class[c]).mean() for c in range(len(class_labels))])
        sens_per_class_mean = np.nan_to_num(sens_per_class_mean)
        sens_per_class_std = np.array([np.array(sens_per_class[c]).std() for c in range(len(class_labels))])
        sens_per_class_std = np.nan_to_num(sens_per_class_std)
        # plt.errorbar(np.arange(len(class_labels)), sens_per_class_mean, yerr=sens_per_class_std, fmt='-o',  solid_capstyle='projecting', capsize=5, label=label)
        plt.plot(sens_per_class_mean, label=label, marker='o', markersize=8)
        plt.ylabel('Sensitivity')
        plt.xticks(np.arange(len(class_labels)),
                            class_labels,
                            rotation='vertical')      
        plt.legend()
        
        data.append((em, prompt_type))

        plt.figure(errorbar_fig)
    plt.tight_layout()
    plt.savefig(Path(results_folder, 'paper_figures',
                f'sensitivity_vs_class_{dataset}_{llm}_{Q}_{A}_{temp_question}_{temp_answer}.pdf'))
    
    
    # Prepare lists to collect expanded data
    expanded_values = []
    expanded_labels = []
    
    # Expand the data into individual points
    for arr, label in data:
        expanded_values.extend(arr)
        expanded_labels.extend([label] * len(arr))
    
    # Create a DataFrame from the expanded data
    df = pd.DataFrame({'Values': expanded_values, 'Label': expanded_labels})
    
    # Plot the violin plot
    plt.figure(figsize=figsize)  # Adjust the figure size if needed
    ax = sns.violinplot(x='Label', y='Values', data=df, split=False)
    ax.set_xticklabels(['Simple', 'Detail', '1-shot'])
    plt.xlabel(None)
    plt.ylabel('Sensitivity')
    # Setting the y-axis limits to cut off values below 0
    plt.ylim(0, None)
    plt.tight_layout()
    plt.savefig(Path(results_folder, 'paper_figures',
                f'sensitivity_vs_prompting_{dataset}_{llm}_{Q}_{A}_{temp_question}_{temp_answer}.pdf'))
    plt.show()
# Out:
# llama3 simple
# Avg Entropy over samples: 0.15689349844926076,Std (over questions): 0.24442056131231674
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 35
#      24 print(llm, prompt_type)
#      25 em = print_test_sensitivity_over_samples(sample_ids,
#      26                                 prompt_type,
#      27                                 llm,
#    (...)
#      32                                 class_labels,
#      33                                 results_folder)
# ---> 35 sens_per_class = sensitivity_per_class(sample_ids,
#      36                                        prompt_type,
#      37                                        llm,
#      38                                        Q,
#      39                                        temp_question,
#      40                                        A,
#      41                                        temp_answer,
#      42                                        class_labels,
#      43                                        results_folder)
#      45 # Add error bars (standard deviation)
#      46 plt.figure(errorbar_fig)
#
# File ~/PycharmProjects/uncertainty-in-llms/util.py:1004, in sensitivity_per_class(sample_ids, prompt_type, llm, Q, temp_question, A, temp_answer, class_labels, results_folder)
#    1001 key = f"{s_id}_{llm}_{Q}_{A}_{temp_question}_{temp_answer}"
#    1003 experiment = data_dict[key]
# -> 1004 target_id = class_labels_to_id[experiment['target']]
#    1006 if target_id != c:
#    1007     continue
#
# KeyError: 'not_entailment'

# %%
# Configure matplotlib to use LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
# Set the global font size
plt.rc('font', size=20)  # Example: set the font size to 14

sns.set_style("whitegrid")
sns.color_palette("colorblind")

figsize=(7.5,4.5)

Q = 30
A = 1  # MUST stay 1
temp_answer = 0.


data = []
errorbar_fig = plt.figure(figsize=figsize)
    
for temp_question in temp_questions:
    
    for llm in ['llama3', 'mixtral']:
        
        for prompt_type in ['simple', 'instruct', 'fewshot']:
            print(llm, prompt_type)
            em = print_test_sensitivity_over_samples(sample_ids,
                                            prompt_type,
                                            llm,
                                            Q,
                                            temp_question,
                                            A,
                                            temp_answer,
                                            class_labels,
                                            results_folder)
    
    
            # Add error bars (standard deviation)
            plt.figure(errorbar_fig)
            if prompt_type == 'instruct':
                label = 'Detail'
            elif prompt_type == 'fewshot':
                label = '1-shot'
            else:
                label = 'Simple'
    
            
            data.append((em.mean(), label, llm, int(temp_question/0.25)))
            
        
        
# Create a DataFrame from the expanded data
df = pd.DataFrame(data, columns=['Sensitivity', 'Strategy', 'LLM', 'Temperature'])
print(df)
# Plot the violin plot
plt.figure(figsize=figsize)  # Adjust the figure size if needed
ax = sns.lineplot(x='Temperature', y='Sensitivity', hue='LLM', style='Strategy', data=df)
ax.set_xticks(np.arange(5)) # <--- set the ticks first
ax.set_xticklabels([r'$0.$', r'$0.25$', r'$0.50$', r'$0.75$', r'$1.$'])
# Setting the y-axis limits to cut off values below 0
plt.ylim(0, None)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.575))
plt.tight_layout()
plt.savefig(Path(results_folder, 'paper_figures',
            f'sensitivity_vs_temperature_{dataset}_{Q}_{A}_{temp_answer}.pdf'))
plt.show()
# Out:
# llama3 simple
# Avg Entropy over samples: 0.15689349844926076,Std (over questions): 0.24442056131231674
# llama3 instruct
# Avg Entropy over samples: 0.21323642968569204,Std (over questions): 0.28925746726542995
# llama3 fewshot
# Avg Entropy over samples: 0.04825207230922011,Std (over questions): 0.16041886179920312
# mixtral simple
# Avg Entropy over samples: 0.19475169146882296,Std (over questions): 0.2779043304966564
# mixtral instruct
# Avg Entropy over samples: 0.1755831897599826,Std (over questions): 0.26380520963434484
# mixtral fewshot
# Avg Entropy over samples: 0.0461713000077939,Std (over questions): 0.15286904169249171
# gpt-3.5 simple
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 26
#      24 for prompt_type in ['simple', 'instruct', 'fewshot']:
#      25     print(llm, prompt_type)
# ---> 26     em = print_test_sensitivity_over_samples(sample_ids,
#      27                                     prompt_type,
#      28                                     llm,
#      29                                     Q,
#      30                                     temp_question,
#      31                                     A,
#      32                                     temp_answer,
#      33                                     class_labels,
#      34                                     results_folder)
#      37     # Add error bars (standard deviation)
#      38     plt.figure(errorbar_fig)
#
# File ~/PycharmProjects/uncertainty-in-llms/util.py:947, in print_test_sensitivity_over_samples(sample_ids, prompt_type, llm, Q, temp_question, A, temp_answer, class_labels, results_folder, noise_amount)
#     943 c_distribution = np.zeros(n_classes)
#     945 key = f"{s_id}_{llm}_{Q}_{A}_{temp_question}_{temp_answer}"
# --> 947 experiment = data_dict[key]
#     949 for q in range(Q):
#     951     pred_id = class_labels_to_id[
#     952         experiment["info_answers"][str(q)][0]]
#
# KeyError: '0_gpt-3.5_30_1_0.0_0.0'
